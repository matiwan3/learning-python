# %%
import requests

# %%
response = requests.get('https://api.covid19api.com/summary').text

# %%
response = requests.get('https://api.covid19api.com/summary').text

# %%
response
# Out:
# '{"ID":"1ed59e45-bd40-417c-9f3b-1164037bb9d3","Message":"","Global":{"NewConfirmed":510457,"TotalConfirmed":624825878,"NewDeaths":2120,"TotalDeaths":6567396,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-10-21T03:07:56.806Z"},"Countries":[{"ID":"0272026c-f9eb-4e3d-a173-31911cffe89c","Country":"Afghanistan","CountryCode":"AF","Slug":"afghanistan","NewConfirmed":54,"TotalConfirmed":201557,"NewDeaths":0,"TotalDeaths":7812,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-10-21T03:07:56.806Z","Premium":{}},{"ID":"210b9b48-3bd2-45f5-8e95-8953bf850553","Country":"Albania","CountryCode":"AL","Slug":"albania","NewConfirmed":28,"TotalConfirmed":332701,"NewDeaths":0,"TotalDeaths":3592,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-10-21T03:07:56.806Z","Premium":{}},{"ID":"63208d7a-cd4d-4d1e-9301-4e475c33c012","Country":"Algeria","CountryCode":"DZ","Slug":"algeria","NewConfirmed":2,"TotalConfirmed":270768,"NewDeaths":0,"TotalDeaths":6881,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-10-21T03:07:56.806Z","Premium":{}},{"ID":"f479fc66-7c0e-47fc-bfd9-5ac7fd56b77b","Country":"Andorra","CountryCode":"AD","Slug":"andorra","NewConfirmed":83,"TotalConfirmed":46449,"NewDeaths":0,"TotalDeaths":155,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-10-21T03:07:56.806Z","Premium":{}},{"ID":"6e86a804-570c-4d17-b482-ce7f497300ba","Country":"Angola","CountryCode":"AO","Slug":"angola","NewConfirmed":0,"TotalConfirmed":103131,"NewDeaths":0,"TotalDeaths":1917,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-10-21T03:07:56.806Z","Premium":{}},{"ID":"ed8fd15f-b55c-4c64-b841-4ee7a4625dbb","Country":"Antarctica","CountryCode":"AQ","Slug":"antarctica","NewConfirmed":0,"TotalConfirmed":11,"NewDeaths":0,"TotalDeaths":0,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-10-21T03:07:56.806Z","Premium":{}},{"ID":"965286c8-794c-45d2-9f10-4e4c08cf67b6","Country":"Antigua and Barbuda","CountryCode":"AG","Slug":"antigua-and-barbuda","NewConfirmed":0,"TotalConfirmed":9106,"NewDeaths":0,"TotalDeaths":146,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-10-21T03:07:56.806Z","Premium":{}},{"ID":"6f77f961-d567-407c-a962-94c923b916b5","Country":"Argentina","CountryCode":"AR","Slug":"argentina","NewConfirmed":0,"TotalConfirmed":9715464,"NewDeaths":0,"TotalDeaths":129970,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-10-21T03:07:56.806Z","Premium":{}},{"ID":"63bee3f7-a3b4-450c-a9a2-85df67701820","Country":"Armenia","CountryCode":"AM","Slug":"armenia","NewConfirmed":0,"TotalConfirmed":444869,"NewDeaths":0,"TotalDeaths":8706,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-10-21T03:07:56.806Z","Premium":{}},{"ID":"2815ee56-5b2d-4955-993d-1df95fafd311","Country":"Australia","CountryCode":"AU","Slug":"australia","NewConfirmed":1093,"TotalConfirmed":10313911,"NewDeaths":6,"TotalDeaths":15496,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-10-21T03:07:56.806Z","Premium":{}},{"ID":"a122bd98-b39c-4675-8f7c-49f8c3609273","Country":"Austria","CountryCode":"AT","Slug":"austria","NewConfirmed":13711,"TotalConfirmed":5369885,"NewDeaths":10,"TotalDeaths":20953,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-10-21T03:07:56.806Z","Premium":{}},{"ID":"f0cb657a-bca2-4d88-8f11-9154d152ad9c","Country":"Azerbaijan","CountryCode":"AZ","Slug":"azerbaijan","NewConfirmed":65,"TotalConfirmed":822751,"NewDeaths":0,"TotalDeaths":9935,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-10-21T03:07:56.806Z","Premium":{}},{"ID":"6b4565b8-bef6-4940-acd9-3fcea5302a90","Country":"Bahamas","CountryCode":"BS","Slug":"bahamas","NewConfirmed":0,"TotalConfirmed":37334,"NewDeaths":0,"TotalDeaths":833,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-10-21T03:07:56.806Z","Premium":{}},{"ID":"d3274c0f-13de-49a7-b0c9-2300a4f1e258","Country":"Bahrain","CountryCode":"BH","Slug":"bahrain","NewConfirmed":312,"TotalConfirmed":686629,"NewDeaths":0,"TotalDeaths":1523,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-10-21T03:07:56.806Z","Premium":{}},{"ID":"62c6a242-8aac-4c86-83e7-3e63a62a11bd","Country":"Bangladesh","Countr ...

# %%
response_info = json.loads(response)

# %%
import json

# %%
response_info = json.loads(response)

# %%
response_info
# Out:
# {'ID': '1ed59e45-bd40-417c-9f3b-1164037bb9d3',
#  'Message': '',
#  'Global': {'NewConfirmed': 510457,
#   'TotalConfirmed': 624825878,
#   'NewDeaths': 2120,
#   'TotalDeaths': 6567396,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z'},
#  'Countries': [{'ID': '0272026c-f9eb-4e3d-a173-31911cffe89c',
#    'Country': 'Afghanistan',
#    'CountryCode': 'AF',
#    'Slug': 'afghanistan',
#    'NewConfirmed': 54,
#    'TotalConfirmed': 201557,
#    'NewDeaths': 0,
#    'TotalDeaths': 7812,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '210b9b48-3bd2-45f5-8e95-8953bf850553',
#    'Country': 'Albania',
#    'CountryCode': 'AL',
#    'Slug': 'albania',
#    'NewConfirmed': 28,
#    'TotalConfirmed': 332701,
#    'NewDeaths': 0,
#    'TotalDeaths': 3592,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '63208d7a-cd4d-4d1e-9301-4e475c33c012',
#    'Country': 'Algeria',
#    'CountryCode': 'DZ',
#    'Slug': 'algeria',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 270768,
#    'NewDeaths': 0,
#    'TotalDeaths': 6881,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'f479fc66-7c0e-47fc-bfd9-5ac7fd56b77b',
#    'Country': 'Andorra',
#    'CountryCode': 'AD',
#    'Slug': 'andorra',
#    'NewConfirmed': 83,
#    'TotalConfirmed': 46449,
#    'NewDeaths': 0,
#    'TotalDeaths': 155,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '6e86a804-570c-4d17-b482-ce7f497300ba',
#    'Country': 'Angola',
#    'CountryCode': 'AO',
#    'Slug': 'angola',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 103131,
#    'NewDeaths': 0,
#    'TotalDeaths': 1917,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'ed8fd15f-b55c-4c64-b841-4ee7a4625dbb',
#    'Country': 'Antarctica',
#    'CountryCode': 'AQ',
#    'Slug': 'antarctica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 11,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '965286c8-794c-45d2-9f10-4e4c08cf67b6',
#    'Country': 'Antigua and Barbuda',
#    'CountryCode': 'AG',
#    'Slug': 'antigua-and-barbuda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 9106,
#    'NewDeaths': 0,
#    'TotalDeaths': 146,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '6f77f961-d567-407c-a962-94c923b916b5',
#    'Country': 'Argentina',
#    'CountryCode': 'AR',
#    'Slug': 'argentina',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 9715464,
#    'NewDeaths': 0,
#    'TotalDeaths': 129970,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '63bee3f7-a3b4-450c-a9a2-85df67701820',
#    'Country': 'Armenia',
#    'CountryCode': 'AM',
#    'Slug': 'armenia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 444869,
#    'NewDeaths': 0,
#    'TotalDeaths': 8706,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '2815ee56-5b2d-4955-993d-1df95fafd311',
#    'Country': 'Australia',
#    'CountryCode': 'AU',
#    'Slug': 'australia',
#    'NewConfirmed': 1093,
#    'TotalConfirmed': 10313911,
#    'NewDeaths': 6,
#    'TotalDeaths': 15496,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'a122bd98-b39c-4675-8f7c-49f8c3609273',
#    'Country': 'Austria',
#    'CountryCode': 'AT',
#    'Slug': 'austria',
#    'NewConfirmed': 13711,
#    'TotalConfirmed': 5369885,
#    'NewDeaths': 10,
#    'TotalDeaths': 20953,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'f0cb657a-bca2-4d88-8f11-9154d152ad9c',
#    'Country': 'Azerbaijan',
#    'CountryCode': 'AZ',
#    'Slug': 'azerbaijan',
#    'NewConfirmed': 65,
#    'TotalConfirmed': 822751,
#    'NewDeaths': 0,
#    'TotalDeaths': 9935,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '6b4565b8-bef6-4940-acd9-3fcea5302a90',
#    'Country': 'Bahamas',
#    'CountryCode': 'BS',
#    'Slug': 'bahamas',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 37334,
#    'NewDeaths': 0,
#    'TotalDeaths': 833,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'd3274c0f-13de-49a7-b0c9-2300a4f1e258',
#    'Country': 'Bahrain',
#    'CountryCode': 'BH',
#    'Slug': 'bahrain',
#    'NewConfirmed': 312,
#    'TotalConfirmed': 686629,
#    'NewDeaths': 0,
#    'TotalDeaths': 1523,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '62c6a242-8aac-4c86-83e7-3e63a62a11bd',
#    'Country': 'Bangladesh',
#    'CountryCode': 'BD',
#    'Slug': 'bangladesh',
#    'NewConfirmed': 300,
#    'TotalConfirmed': 2033419,
#    'NewDeaths': 2,
#    'TotalDeaths': 29410,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'bcd187e5-4727-47b8-8f3e-647d8965f3a4',
#    'Country': 'Barbados',
#    'CountryCode': 'BB',
#    'Slug': 'barbados',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 103014,
#    'NewDeaths': 0,
#    'TotalDeaths': 560,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'c7e268d2-3c8c-4e6a-a492-482339020e56',
#    'Country': 'Belarus',
#    'CountryCode': 'BY',
#    'Slug': 'belarus',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 994037,
#    'NewDeaths': 0,
#    'TotalDeaths': 7118,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '03a8cd2c-65df-431b-b711-e6d39f90ddba',
#    'Country': 'Belgium',
#    'CountryCode': 'BE',
#    'Slug': 'belgium',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4594338,
#    'NewDeaths': 0,
#    'TotalDeaths': 32810,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '765c48ff-abf6-478f-90ad-c8a15234cffe',
#    'Country': 'Belize',
#    'CountryCode': 'BZ',
#    'Slug': 'belize',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 68926,
#    'NewDeaths': 0,
#    'TotalDeaths': 687,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'f9265ea6-35c7-46a1-9448-c44dc7759889',
#    'Country': 'Benin',
#    'CountryCode': 'BJ',
#    'Slug': 'benin',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 27782,
#    'NewDeaths': 0,
#    'TotalDeaths': 163,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'bfcdee2d-03db-424e-ac5f-2ca1fbbdde26',
#    'Country': 'Bhutan',
#    'CountryCode': 'BT',
#    'Slug': 'bhutan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 62248,
#    'NewDeaths': 0,
#    'TotalDeaths': 21,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '0d9e2cf5-8df8-4602-8af6-c8db4f444dde',
#    'Country': 'Bolivia',
#    'CountryCode': 'BO',
#    'Slug': 'bolivia',
#    'NewConfirmed': 86,
#    'TotalConfirmed': 1109123,
#    'NewDeaths': 0,
#    'TotalDeaths': 22237,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '9e80547d-ce8f-40c8-8cb3-4b5c5a95e9e3',
#    'Country': 'Bosnia and Herzegovina',
#    'CountryCode': 'BA',
#    'Slug': 'bosnia-and-herzegovina',
#    'NewConfirmed': 40,
#    'TotalConfirmed': 399584,
#    'NewDeaths': 1,
#    'TotalDeaths': 16161,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'c40f52fb-a031-45b5-87ee-c5d197f5e179',
#    'Country': 'Botswana',
#    'CountryCode': 'BW',
#    'Slug': 'botswana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 326344,
#    'NewDeaths': 0,
#    'TotalDeaths': 2790,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '8e03dc8c-2655-4e0b-8eef-71d2a1ee1ae5',
#    'Country': 'Brazil',
#    'CountryCode': 'BR',
#    'Slug': 'brazil',
#    'NewConfirmed': 24858,
#    'TotalConfirmed': 34771320,
#    'NewDeaths': 279,
#    'TotalDeaths': 687423,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '901f4993-465b-4b8a-9a0c-2c01df64262f',
#    'Country': 'Brunei Darussalam',
#    'CountryCode': 'BN',
#    'Slug': 'brunei',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 234582,
#    'NewDeaths': 0,
#    'TotalDeaths': 225,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'dd667310-c222-4444-b2e0-8aedc396559c',
#    'Country': 'Bulgaria',
#    'CountryCode': 'BG',
#    'Slug': 'bulgaria',
#    'NewConfirmed': 630,
#    'TotalConfirmed': 1272645,
#    'NewDeaths': 11,
#    'TotalDeaths': 37812,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '65bca9e6-78d7-4412-b462-1c452911ae57',
#    'Country': 'Burkina Faso',
#    'CountryCode': 'BF',
#    'Slug': 'burkina-faso',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 21631,
#    'NewDeaths': 0,
#    'TotalDeaths': 387,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '479f517a-0cbb-4164-9275-c121a639c39b',
#    'Country': 'Burundi',
#    'CountryCode': 'BI',
#    'Slug': 'burundi',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 50372,
#    'NewDeaths': 0,
#    'TotalDeaths': 38,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'be6c3b9a-552a-4fdd-a37e-bf927cb74e86',
#    'Country': 'Cambodia',
#    'CountryCode': 'KH',
#    'Slug': 'cambodia',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 137976,
#    'NewDeaths': 0,
#    'TotalDeaths': 3056,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '42286f65-0715-40cd-a413-42fe631e293c',
#    'Country': 'Cameroon',
#    'CountryCode': 'CM',
#    'Slug': 'cameroon',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 121652,
#    'NewDeaths': 0,
#    'TotalDeaths': 1935,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'dcc2efa4-8757-4111-8906-d1c051aa4c8b',
#    'Country': 'Canada',
#    'CountryCode': 'CA',
#    'Slug': 'canada',
#    'NewConfirmed': 1107,
#    'TotalConfirmed': 3721413,
#    'NewDeaths': 10,
#    'TotalDeaths': 41036,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '1a32d3b0-5f11-41fd-bfe6-a95646c214bf',
#    'Country': 'Cape Verde',
#    'CountryCode': 'CV',
#    'Slug': 'cape-verde',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 62397,
#    'NewDeaths': 0,
#    'TotalDeaths': 410,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '7d46d507-d935-403b-810a-e0e2fe999c1e',
#    'Country': 'Central African Republic',
#    'CountryCode': 'CF',
#    'Slug': 'central-african-republic',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15151,
#    'NewDeaths': 0,
#    'TotalDeaths': 113,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '806ea21a-cd55-429c-a7b8-2344c569182e',
#    'Country': 'Chad',
#    'CountryCode': 'TD',
#    'Slug': 'chad',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7613,
#    'NewDeaths': 0,
#    'TotalDeaths': 193,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '53feca91-67aa-4973-b56b-884cf801f680',
#    'Country': 'Chile',
#    'CountryCode': 'CL',
#    'Slug': 'chile',
#    'NewConfirmed': 5743,
#    'TotalConfirmed': 4690513,
#    'NewDeaths': 4,
#    'TotalDeaths': 61459,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '8534e328-08e7-4b51-ab21-72c3760c4458',
#    'Country': 'China',
#    'CountryCode': 'CN',
#    'Slug': 'china',
#    'NewConfirmed': 5335,
#    'TotalConfirmed': 2110808,
#    'NewDeaths': 12,
#    'TotalDeaths': 15529,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'fe562f03-685d-49a9-93cd-c19f37783c6d',
#    'Country': 'Colombia',
#    'CountryCode': 'CO',
#    'Slug': 'colombia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 6308558,
#    'NewDeaths': 0,
#    'TotalDeaths': 141820,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '514ea4ab-b601-45e6-a376-e92054ecc610',
#    'Country': 'Comoros',
#    'CountryCode': 'KM',
#    'Slug': 'comoros',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8481,
#    'NewDeaths': 0,
#    'TotalDeaths': 161,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '7db86baa-a2fc-4dd9-996a-bef4203da289',
#    'Country': 'Congo (Brazzaville)',
#    'CountryCode': 'CG',
#    'Slug': 'congo-brazzaville',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 24837,
#    'NewDeaths': 0,
#    'TotalDeaths': 386,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'cfd33788-a19b-400d-b9c8-e45a4e38fad8',
#    'Country': 'Congo (Kinshasa)',
#    'CountryCode': 'CD',
#    'Slug': 'congo-kinshasa',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 92972,
#    'NewDeaths': 0,
#    'TotalDeaths': 1444,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'de052797-903b-4712-b85a-ce4303e1caea',
#    'Country': 'Costa Rica',
#    'CountryCode': 'CR',
#    'Slug': 'costa-rica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1130568,
#    'NewDeaths': 0,
#    'TotalDeaths': 8982,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '799b502d-f01b-4b0e-adab-2ce4694162ad',
#    'Country': 'Croatia',
#    'CountryCode': 'HR',
#    'Slug': 'croatia',
#    'NewConfirmed': 755,
#    'TotalConfirmed': 1242909,
#    'NewDeaths': 7,
#    'TotalDeaths': 17046,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '90401c10-77eb-411c-a2ab-38ff0a5f5044',
#    'Country': 'Cuba',
#    'CountryCode': 'CU',
#    'Slug': 'cuba',
#    'NewConfirmed': 3,
#    'TotalConfirmed': 1111263,
#    'NewDeaths': 0,
#    'TotalDeaths': 8530,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'df145ff6-2109-48bd-892e-d4b1cbc7b629',
#    'Country': 'Cyprus',
#    'CountryCode': 'CY',
#    'Slug': 'cyprus',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 593542,
#    'NewDeaths': 0,
#    'TotalDeaths': 1189,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'bfc28bcf-b158-4610-87d1-b7f600b2d969',
#    'Country': 'Czech Republic',
#    'CountryCode': 'CZ',
#    'Slug': 'czech-republic',
#    'NewConfirmed': 1800,
#    'TotalConfirmed': 4147736,
#    'NewDeaths': 27,
#    'TotalDeaths': 41454,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '9e86a444-214f-45d1-9d8a-98a7a659ff31',
#    'Country': "Côte d'Ivoire",
#    'CountryCode': 'CI',
#    'Slug': 'cote-divoire',
#    'NewConfirmed': 55,
#    'TotalConfirmed': 87657,
#    'NewDeaths': 0,
#    'TotalDeaths': 827,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'bfa0889f-9ceb-4358-a489-e8e8b1d95b24',
#    'Country': 'Denmark',
#    'CountryCode': 'DK',
#    'Slug': 'denmark',
#    'NewConfirmed': 1444,
#    'TotalConfirmed': 3370464,
#    'NewDeaths': 16,
#    'TotalDeaths': 7271,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'c71e0679-b5a4-4f57-94cd-f7da4992d860',
#    'Country': 'Djibouti',
#    'CountryCode': 'DJ',
#    'Slug': 'djibouti',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15690,
#    'NewDeaths': 0,
#    'TotalDeaths': 189,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '4ab45482-4a9b-42d7-8245-d8bcb28100c4',
#    'Country': 'Dominica',
#    'CountryCode': 'DM',
#    'Slug': 'dominica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15760,
#    'NewDeaths': 0,
#    'TotalDeaths': 74,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'c46e5021-84d0-4446-8389-9446cbdc5d6a',
#    'Country': 'Dominican Republic',
#    'CountryCode': 'DO',
#    'Slug': 'dominican-republic',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 647205,
#    'NewDeaths': 0,
#    'TotalDeaths': 4384,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'b48d29b4-5752-4845-af71-a867d5cffa7c',
#    'Country': 'Ecuador',
#    'CountryCode': 'EC',
#    'Slug': 'ecuador',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1006922,
#    'NewDeaths': 0,
#    'TotalDeaths': 35904,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'cdcc192f-2755-4763-b6c9-af35cfbb7184',
#    'Country': 'Egypt',
#    'CountryCode': 'EG',
#    'Slug': 'egypt',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 515645,
#    'NewDeaths': 1,
#    'TotalDeaths': 24798,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '8bc9b38a-7d79-4545-ba6b-2ecf3ecf3802',
#    'Country': 'El Salvador',
#    'CountryCode': 'SV',
#    'Slug': 'el-salvador',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 201785,
#    'NewDeaths': 0,
#    'TotalDeaths': 4230,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '53fe4d7a-c7cd-48a0-926a-90d009d7e1d2',
#    'Country': 'Equatorial Guinea',
#    'CountryCode': 'GQ',
#    'Slug': 'equatorial-guinea',
#    'NewConfirmed': 14,
#    'TotalConfirmed': 17131,
#    'NewDeaths': 0,
#    'TotalDeaths': 183,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '2d187a1f-0b34-40df-aeb4-7968baa18112',
#    'Country': 'Eritrea',
#    'CountryCode': 'ER',
#    'Slug': 'eritrea',
#    'NewConfirmed': 3,
#    'TotalConfirmed': 10185,
#    'NewDeaths': 0,
#    'TotalDeaths': 103,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '8bc650be-6519-44dc-bf97-3b0d8805cc23',
#    'Country': 'Estonia',
#    'CountryCode': 'EE',
#    'Slug': 'estonia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 605622,
#    'NewDeaths': 0,
#    'TotalDeaths': 2729,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'e658bada-4d72-413e-b2fd-020f5f1563ff',
#    'Country': 'Ethiopia',
#    'CountryCode': 'ET',
#    'Slug': 'ethiopia',
#    'NewConfirmed': 15,
#    'TotalConfirmed': 493818,
#    'NewDeaths': 0,
#    'TotalDeaths': 7572,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'bea63fed-c31e-46d1-8f43-778c69831e80',
#    'Country': 'Fiji',
#    'CountryCode': 'FJ',
#    'Slug': 'fiji',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 68248,
#    'NewDeaths': 0,
#    'TotalDeaths': 878,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '349d8b03-2512-4c7c-801c-6de5fa164d1b',
#    'Country': 'Finland',
#    'CountryCode': 'FI',
#    'Slug': 'finland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1323455,
#    'NewDeaths': 0,
#    'TotalDeaths': 6242,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'acde5dd5-b5c6-42c9-8896-3a2fcd6d9fca',
#    'Country': 'France',
#    'CountryCode': 'FR',
#    'Slug': 'france',
#    'NewConfirmed': 63062,
#    'TotalConfirmed': 36636069,
#    'NewDeaths': 106,
#    'TotalDeaths': 157227,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '6bdb26bc-df10-4c66-812d-9b0a4e0093ad',
#    'Country': 'Gabon',
#    'CountryCode': 'GA',
#    'Slug': 'gabon',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 48810,
#    'NewDeaths': 0,
#    'TotalDeaths': 306,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'ff1edab4-2f8b-4d8f-89e7-eba7ed635c81',
#    'Country': 'Gambia',
#    'CountryCode': 'GM',
#    'Slug': 'gambia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 12508,
#    'NewDeaths': 0,
#    'TotalDeaths': 372,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '9499af82-bf42-49ba-b913-b0361f7acd50',
#    'Country': 'Georgia',
#    'CountryCode': 'GE',
#    'Slug': 'georgia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1780691,
#    'NewDeaths': 0,
#    'TotalDeaths': 16900,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'fc40f677-d067-4a18-8b43-3d6cb7bcb86a',
#    'Country': 'Germany',
#    'CountryCode': 'DE',
#    'Slug': 'germany',
#    'NewConfirmed': 116806,
#    'TotalConfirmed': 35005769,
#    'NewDeaths': 223,
#    'TotalDeaths': 152100,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '12376334-f3f9-4c4a-8ea5-340671502a40',
#    'Country': 'Ghana',
#    'CountryCode': 'GH',
#    'Slug': 'ghana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 170321,
#    'NewDeaths': 0,
#    'TotalDeaths': 1460,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '3728a57c-3597-462e-8a8a-ba2532108276',
#    'Country': 'Greece',
#    'CountryCode': 'GR',
#    'Slug': 'greece',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5081981,
#    'NewDeaths': 0,
#    'TotalDeaths': 33426,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'bbe379d5-c5cb-49d8-aa3c-a18e5010fe60',
#    'Country': 'Grenada',
#    'CountryCode': 'GD',
#    'Slug': 'grenada',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 19584,
#    'NewDeaths': 0,
#    'TotalDeaths': 237,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '401812cd-91ca-41ba-beb8-d38bc91d733c',
#    'Country': 'Guatemala',
#    'CountryCode': 'GT',
#    'Slug': 'guatemala',
#    'NewConfirmed': 698,
#    'TotalConfirmed': 1134947,
#    'NewDeaths': 2,
#    'TotalDeaths': 19861,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '9013f2ff-3818-4e3e-862e-d224e4552df5',
#    'Country': 'Guinea',
#    'CountryCode': 'GN',
#    'Slug': 'guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 37999,
#    'NewDeaths': 0,
#    'TotalDeaths': 456,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'b6bc3da1-1978-49cb-8efe-55158b029b92',
#    'Country': 'Guinea-Bissau',
#    'CountryCode': 'GW',
#    'Slug': 'guinea-bissau',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8831,
#    'NewDeaths': 0,
#    'TotalDeaths': 176,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'cc5f2928-90a3-435f-a86f-8fae0a420dfc',
#    'Country': 'Guyana',
#    'CountryCode': 'GY',
#    'Slug': 'guyana',
#    'NewConfirmed': 14,
#    'TotalConfirmed': 71418,
#    'NewDeaths': 0,
#    'TotalDeaths': 1281,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'ebeeca17-f8d8-47ce-a128-80bf73244573',
#    'Country': 'Haiti',
#    'CountryCode': 'HT',
#    'Slug': 'haiti',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 33764,
#    'NewDeaths': 0,
#    'TotalDeaths': 857,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'a1d5a1b9-0413-47b3-9d4d-77511d910df0',
#    'Country': 'Holy See (Vatican City State)',
#    'CountryCode': 'VA',
#    'Slug': 'holy-see-vatican-city-state',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 29,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'cff9caf4-f45c-43d8-b7c6-59513ab3b8f1',
#    'Country': 'Honduras',
#    'CountryCode': 'HN',
#    'Slug': 'honduras',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 456886,
#    'NewDeaths': 0,
#    'TotalDeaths': 11007,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'abac5b43-2bbf-4b5c-97f1-65dfa8fb81ea',
#    'Country': 'Hungary',
#    'CountryCode': 'HU',
#    'Slug': 'hungary',
#    'NewConfirmed': 11947,
#    'TotalConfirmed': 2132490,
#    'NewDeaths': 118,
#    'TotalDeaths': 47798,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'f8724241-d81f-4ddc-8406-a6e4c0012b4f',
#    'Country': 'Iceland',
#    'CountryCode': 'IS',
#    'Slug': 'iceland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 206134,
#    'NewDeaths': 0,
#    'TotalDeaths': 213,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '5d63c4cc-c1c9-4e7f-a0c2-9962c7c82ed6',
#    'Country': 'India',
#    'CountryCode': 'IN',
#    'Slug': 'india',
#    'NewConfirmed': 2141,
#    'TotalConfirmed': 44636517,
#    'NewDeaths': 20,
#    'TotalDeaths': 528943,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'ef21e1af-037e-4ecc-b957-8b262b4cf0ee',
#    'Country': 'Indonesia',
#    'CountryCode': 'ID',
#    'Slug': 'indonesia',
#    'NewConfirmed': 2390,
#    'TotalConfirmed': 6462655,
#    'NewDeaths': 16,
#    'TotalDeaths': 158361,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'aaf06eac-789d-4bc4-a895-29978f2bed6d',
#    'Country': 'Iran, Islamic Republic of',
#    'CountryCode': 'IR',
#    'Slug': 'iran',
#    'NewConfirmed': 345,
#    'TotalConfirmed': 7555355,
#    'NewDeaths': 4,
#    'TotalDeaths': 144531,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '30183f51-e487-41cc-aa26-4c1673edba54',
#    'Country': 'Iraq',
#    'CountryCode': 'IQ',
#    'Slug': 'iraq',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2460868,
#    'NewDeaths': 0,
#    'TotalDeaths': 25356,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '7972e43d-a16c-418b-bc7d-46cc4f3b184b',
#    'Country': 'Ireland',
#    'CountryCode': 'IE',
#    'Slug': 'ireland',
#    'NewConfirmed': 2076,
#    'TotalConfirmed': 1670377,
#    'NewDeaths': 22,
#    'TotalDeaths': 8010,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'bdf0c870-ed52-4fef-b0f5-49eea34b18e0',
#    'Country': 'Israel',
#    'CountryCode': 'IL',
#    'Slug': 'israel',
#    'NewConfirmed': 971,
#    'TotalConfirmed': 4675027,
#    'NewDeaths': 0,
#    'TotalDeaths': 11728,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '08e7882d-e32f-43bc-9008-da85f03c896b',
#    'Country': 'Italy',
#    'CountryCode': 'IT',
#    'Slug': 'italy',
#    'NewConfirmed': 41703,
#    'TotalConfirmed': 23214073,
#    'NewDeaths': 81,
#    'TotalDeaths': 178275,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'cdf59560-35ae-4273-9014-149218b8f88d',
#    'Country': 'Jamaica',
#    'CountryCode': 'JM',
#    'Slug': 'jamaica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 151931,
#    'NewDeaths': 0,
#    'TotalDeaths': 3320,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '3ed38fe6-4346-4fd7-beaa-9bd4330810fc',
#    'Country': 'Japan',
#    'CountryCode': 'JP',
#    'Slug': 'japan',
#    'NewConfirmed': 43555,
#    'TotalConfirmed': 21887525,
#    'NewDeaths': 68,
#    'TotalDeaths': 46120,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'dff74b87-28aa-4ceb-8343-095d4b499803',
#    'Country': 'Jordan',
#    'CountryCode': 'JO',
#    'Slug': 'jordan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1746997,
#    'NewDeaths': 0,
#    'TotalDeaths': 14122,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'e1cac802-cc37-4c0a-8154-bd6ac3ab9c56',
#    'Country': 'Kazakhstan',
#    'CountryCode': 'KZ',
#    'Slug': 'kazakhstan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1484400,
#    'NewDeaths': 0,
#    'TotalDeaths': 19052,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'cb960cca-6f46-405c-9cbb-a8ec39223141',
#    'Country': 'Kenya',
#    'CountryCode': 'KE',
#    'Slug': 'kenya',
#    'NewConfirmed': 31,
#    'TotalConfirmed': 338678,
#    'NewDeaths': 0,
#    'TotalDeaths': 5678,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '1c93ff84-1017-4d2c-bad4-7d85508f4097',
#    'Country': 'Kiribati',
#    'CountryCode': 'KI',
#    'Slug': 'kiribati',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3430,
#    'NewDeaths': 0,
#    'TotalDeaths': 13,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'ee3386e7-d9a0-4964-8015-0c22e07e38bb',
#    'Country': 'Korea (North)',
#    'CountryCode': 'KP',
#    'Slug': 'korea-north',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1,
#    'NewDeaths': 0,
#    'TotalDeaths': 6,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '534acb8f-a7fe-4511-bbcb-57f5363921a2',
#    'Country': 'Korea (South)',
#    'CountryCode': 'KR',
#    'Slug': 'korea-south',
#    'NewConfirmed': 25369,
#    'TotalConfirmed': 25219546,
#    'NewDeaths': 23,
#    'TotalDeaths': 28922,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '59bcde27-444b-46e5-a4fe-5a7f56da583f',
#    'Country': 'Kuwait',
#    'CountryCode': 'KW',
#    'Slug': 'kuwait',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 661335,
#    'NewDeaths': 0,
#    'TotalDeaths': 2565,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '1a42303a-6eab-4bad-8c58-7d18cc6826b9',
#    'Country': 'Kyrgyzstan',
#    'CountryCode': 'KG',
#    'Slug': 'kyrgyzstan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 206334,
#    'NewDeaths': 0,
#    'TotalDeaths': 2991,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'ce812a55-898e-4a67-8da1-6662620b11df',
#    'Country': 'Lao PDR',
#    'CountryCode': 'LA',
#    'Slug': 'lao-pdr',
#    'NewConfirmed': 42,
#    'TotalConfirmed': 216158,
#    'NewDeaths': 0,
#    'TotalDeaths': 758,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '3a647319-1b60-4ed5-a38b-ca777c6f500e',
#    'Country': 'Latvia',
#    'CountryCode': 'LV',
#    'Slug': 'latvia',
#    'NewConfirmed': 918,
#    'TotalConfirmed': 946092,
#    'NewDeaths': 0,
#    'TotalDeaths': 6036,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'b3ff12cc-7c18-4ae5-92a4-5e61dadf92e5',
#    'Country': 'Lebanon',
#    'CountryCode': 'LB',
#    'Slug': 'lebanon',
#    'NewConfirmed': 832,
#    'TotalConfirmed': 1217831,
#    'NewDeaths': 8,
#    'TotalDeaths': 10696,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '412e118b-9e52-43d3-b5ea-62e540a121b1',
#    'Country': 'Lesotho',
#    'CountryCode': 'LS',
#    'Slug': 'lesotho',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 34490,
#    'NewDeaths': 0,
#    'TotalDeaths': 706,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'ff76ae2a-7339-447c-b6df-9eea52805b14',
#    'Country': 'Liberia',
#    'CountryCode': 'LR',
#    'Slug': 'liberia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7988,
#    'NewDeaths': 0,
#    'TotalDeaths': 294,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '22ee8bc4-5407-46f4-b09d-0a072f592025',
#    'Country': 'Libya',
#    'CountryCode': 'LY',
#    'Slug': 'libya',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 507024,
#    'NewDeaths': 0,
#    'TotalDeaths': 6437,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '7c38c3cb-5665-41da-9cdf-ccc81498cdb0',
#    'Country': 'Liechtenstein',
#    'CountryCode': 'LI',
#    'Slug': 'liechtenstein',
#    'NewConfirmed': 31,
#    'TotalConfirmed': 20465,
#    'NewDeaths': 0,
#    'TotalDeaths': 86,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '2855f54b-15cb-447b-8038-879148c5f694',
#    'Country': 'Lithuania',
#    'CountryCode': 'LT',
#    'Slug': 'lithuania',
#    'NewConfirmed': 756,
#    'TotalConfirmed': 1263538,
#    'NewDeaths': 0,
#    'TotalDeaths': 9369,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'b8ef5ac3-3e92-446d-a668-748b6668d4d2',
#    'Country': 'Luxembourg',
#    'CountryCode': 'LU',
#    'Slug': 'luxembourg',
#    'NewConfirmed': 375,
#    'TotalConfirmed': 299022,
#    'NewDeaths': 0,
#    'TotalDeaths': 1140,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'bc2c7d1e-9aed-4798-88ff-2f27586b992e',
#    'Country': 'Macedonia, Republic of',
#    'CountryCode': 'MK',
#    'Slug': 'macedonia',
#    'NewConfirmed': 102,
#    'TotalConfirmed': 343824,
#    'NewDeaths': 2,
#    'TotalDeaths': 9556,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '44b48fd7-a3d6-4234-81da-05c13aaac651',
#    'Country': 'Madagascar',
#    'CountryCode': 'MG',
#    'Slug': 'madagascar',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 66687,
#    'NewDeaths': 0,
#    'TotalDeaths': 1410,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '3c037b3c-a368-4cf6-a7b5-19ce80eb0bbb',
#    'Country': 'Malawi',
#    'CountryCode': 'MW',
#    'Slug': 'malawi',
#    'NewConfirmed': 3,
#    'TotalConfirmed': 88064,
#    'NewDeaths': 0,
#    'TotalDeaths': 2683,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '61dcc3bf-95b8-453c-9511-0fd5fa9853b7',
#    'Country': 'Malaysia',
#    'CountryCode': 'MY',
#    'Slug': 'malaysia',
#    'NewConfirmed': 2295,
#    'TotalConfirmed': 4872570,
#    'NewDeaths': 3,
#    'TotalDeaths': 36429,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '872565da-e4cd-4798-9311-754a482eb870',
#    'Country': 'Maldives',
#    'CountryCode': 'MV',
#    'Slug': 'maldives',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 185194,
#    'NewDeaths': 0,
#    'TotalDeaths': 308,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'eb4e38ca-8a05-4627-a812-953e5e8d8cf4',
#    'Country': 'Mali',
#    'CountryCode': 'ML',
#    'Slug': 'mali',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 32712,
#    'NewDeaths': 0,
#    'TotalDeaths': 742,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '6077ed21-ed8f-4e68-b23f-37711291ca0b',
#    'Country': 'Malta',
#    'CountryCode': 'MT',
#    'Slug': 'malta',
#    'NewConfirmed': 31,
#    'TotalConfirmed': 115103,
#    'NewDeaths': 0,
#    'TotalDeaths': 806,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'c56e5030-a205-4db6-b258-d0e1c28f2759',
#    'Country': 'Marshall Islands',
#    'CountryCode': 'MH',
#    'Slug': 'marshall-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15389,
#    'NewDeaths': 0,
#    'TotalDeaths': 17,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '636a5ea6-f4e8-4dcb-aec3-85812f5ccee4',
#    'Country': 'Mauritania',
#    'CountryCode': 'MR',
#    'Slug': 'mauritania',
#    'NewConfirmed': 31,
#    'TotalConfirmed': 63194,
#    'NewDeaths': 0,
#    'TotalDeaths': 995,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '0853a5fd-c524-4526-bab3-1571bfb67624',
#    'Country': 'Mauritius',
#    'CountryCode': 'MU',
#    'Slug': 'mauritius',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 263780,
#    'NewDeaths': 0,
#    'TotalDeaths': 1032,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'bdc34b71-ac6e-48ed-9e70-d931e19df352',
#    'Country': 'Mexico',
#    'CountryCode': 'MX',
#    'Slug': 'mexico',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7103339,
#    'NewDeaths': 0,
#    'TotalDeaths': 330279,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'eb42150a-2f20-4d71-ae50-c9a90008ab49',
#    'Country': 'Micronesia, Federated States of',
#    'CountryCode': 'FM',
#    'Slug': 'micronesia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 21815,
#    'NewDeaths': 0,
#    'TotalDeaths': 55,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'fb14a687-eb71-4c0b-9226-a68767104a07',
#    'Country': 'Moldova',
#    'CountryCode': 'MD',
#    'Slug': 'moldova',
#    'NewConfirmed': 623,
#    'TotalConfirmed': 592535,
#    'NewDeaths': 9,
#    'TotalDeaths': 11879,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '88849eb5-fba4-430f-b70c-4667ab47b082',
#    'Country': 'Monaco',
#    'CountryCode': 'MC',
#    'Slug': 'monaco',
#    'NewConfirmed': 44,
#    'TotalConfirmed': 14852,
#    'NewDeaths': 0,
#    'TotalDeaths': 63,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'a28a555f-2f34-442b-a334-23e65947933e',
#    'Country': 'Mongolia',
#    'CountryCode': 'MN',
#    'Slug': 'mongolia',
#    'NewConfirmed': 35,
#    'TotalConfirmed': 984144,
#    'NewDeaths': 0,
#    'TotalDeaths': 2131,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'aaa670fa-75d4-43d4-89af-83079c41e06e',
#    'Country': 'Montenegro',
#    'CountryCode': 'ME',
#    'Slug': 'montenegro',
#    'NewConfirmed': 73,
#    'TotalConfirmed': 282052,
#    'NewDeaths': 0,
#    'TotalDeaths': 2784,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'e9c3b448-6a50-4102-a9e8-6ff1c3a84f0d',
#    'Country': 'Morocco',
#    'CountryCode': 'MA',
#    'Slug': 'morocco',
#    'NewConfirmed': 36,
#    'TotalConfirmed': 1265301,
#    'NewDeaths': 0,
#    'TotalDeaths': 16280,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'a9cf29a5-7b4d-4692-9bb7-396189d38353',
#    'Country': 'Mozambique',
#    'CountryCode': 'MZ',
#    'Slug': 'mozambique',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 230370,
#    'NewDeaths': 0,
#    'TotalDeaths': 2224,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '19dd4f13-faf6-47b2-bd81-f82b639b165d',
#    'Country': 'Myanmar',
#    'CountryCode': 'MM',
#    'Slug': 'myanmar',
#    'NewConfirmed': 277,
#    'TotalConfirmed': 629653,
#    'NewDeaths': 1,
#    'TotalDeaths': 19472,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '9d35bbff-91f8-4d26-a680-c644899ab93f',
#    'Country': 'Namibia',
#    'CountryCode': 'NA',
#    'Slug': 'namibia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 169253,
#    'NewDeaths': 0,
#    'TotalDeaths': 4080,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '68e6356f-91da-48ca-951d-0f22723fbcb0',
#    'Country': 'Nauru',
#    'CountryCode': 'NR',
#    'Slug': 'nauru',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4611,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'b3057fae-c96e-4087-ad58-e1fea117d57f',
#    'Country': 'Nepal',
#    'CountryCode': 'NP',
#    'Slug': 'nepal',
#    'NewConfirmed': 42,
#    'TotalConfirmed': 1000275,
#    'NewDeaths': 0,
#    'TotalDeaths': 12018,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '4d13ec8c-688b-4ae3-9a18-4e4f97416510',
#    'Country': 'Netherlands',
#    'CountryCode': 'NL',
#    'Slug': 'netherlands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8487576,
#    'NewDeaths': 0,
#    'TotalDeaths': 22748,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '8452a1f9-c146-401f-a96a-aed11a83edaf',
#    'Country': 'New Zealand',
#    'CountryCode': 'NZ',
#    'Slug': 'new-zealand',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1821362,
#    'NewDeaths': 0,
#    'TotalDeaths': 2066,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '0eb02294-cbe8-4f9b-ab13-e13ad57cce85',
#    'Country': 'Nicaragua',
#    'CountryCode': 'NI',
#    'Slug': 'nicaragua',
#    'NewConfirmed': 25,
#    'TotalConfirmed': 15145,
#    'NewDeaths': 0,
#    'TotalDeaths': 245,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'd37b0771-7114-4f4b-b101-16b1d061185b',
#    'Country': 'Niger',
#    'CountryCode': 'NE',
#    'Slug': 'niger',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 9415,
#    'NewDeaths': 0,
#    'TotalDeaths': 314,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '741112bc-b7ef-4ee8-89ab-985f2c988df1',
#    'Country': 'Nigeria',
#    'CountryCode': 'NG',
#    'Slug': 'nigeria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 265937,
#    'NewDeaths': 0,
#    'TotalDeaths': 3155,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '700d9583-cab0-4439-b7a4-e13519f37f70',
#    'Country': 'Norway',
#    'CountryCode': 'NO',
#    'Slug': 'norway',
#    'NewConfirmed': 83,
#    'TotalConfirmed': 1463751,
#    'NewDeaths': 1,
#    'TotalDeaths': 4154,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '2565a07b-3c98-41f2-82b3-6f57c0e0c304',
#    'Country': 'Oman',
#    'CountryCode': 'OM',
#    'Slug': 'oman',
#    'NewConfirmed': 236,
#    'TotalConfirmed': 398660,
#    'NewDeaths': 0,
#    'TotalDeaths': 4628,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '03df6156-3e91-47eb-9165-03486d5b20bd',
#    'Country': 'Pakistan',
#    'CountryCode': 'PK',
#    'Slug': 'pakistan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1572778,
#    'NewDeaths': 0,
#    'TotalDeaths': 30619,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'de743d91-70f7-4b60-b77f-daa60c9bad45',
#    'Country': 'Palau',
#    'CountryCode': 'PW',
#    'Slug': 'palau',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5490,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '3e12c0b0-d027-464f-bf2c-5cc295a2211b',
#    'Country': 'Palestinian Territory',
#    'CountryCode': 'PS',
#    'Slug': 'palestine',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 702804,
#    'NewDeaths': 0,
#    'TotalDeaths': 5707,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '648e5b7a-ef11-495d-973e-f31b23b950e4',
#    'Country': 'Panama',
#    'CountryCode': 'PA',
#    'Slug': 'panama',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 989005,
#    'NewDeaths': 0,
#    'TotalDeaths': 8506,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '3bd6d454-bf17-430b-98f0-3ec301bdf271',
#    'Country': 'Papua New Guinea',
#    'CountryCode': 'PG',
#    'Slug': 'papua-new-guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 45264,
#    'NewDeaths': 0,
#    'TotalDeaths': 668,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '0f779d8c-f371-4350-88f7-54a578cd4fcc',
#    'Country': 'Paraguay',
#    'CountryCode': 'PY',
#    'Slug': 'paraguay',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 717260,
#    'NewDeaths': 0,
#    'TotalDeaths': 19596,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '72df5bb4-c5c6-443d-8920-6421a4287685',
#    'Country': 'Peru',
#    'CountryCode': 'PE',
#    'Slug': 'peru',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4150737,
#    'NewDeaths': 0,
#    'TotalDeaths': 216877,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '4734ea9c-e930-46fd-ae65-2b45b6a58b51',
#    'Country': 'Philippines',
#    'CountryCode': 'PH',
#    'Slug': 'philippines',
#    'NewConfirmed': 1288,
#    'TotalConfirmed': 3987316,
#    'NewDeaths': 44,
#    'TotalDeaths': 63625,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '5fcf3e84-0680-4fad-8441-5c6ccf51b2cf',
#    'Country': 'Poland',
#    'CountryCode': 'PL',
#    'Slug': 'poland',
#    'NewConfirmed': 1611,
#    'TotalConfirmed': 6330904,
#    'NewDeaths': 42,
#    'TotalDeaths': 117973,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '1728291f-49ac-4f0b-a3f5-03fd56c33811',
#    'Country': 'Portugal',
#    'CountryCode': 'PT',
#    'Slug': 'portugal',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5509424,
#    'NewDeaths': 0,
#    'TotalDeaths': 25128,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '83b4a6fd-9ee1-49a1-943f-f23b3783ab25',
#    'Country': 'Qatar',
#    'CountryCode': 'QA',
#    'Slug': 'qatar',
#    'NewConfirmed': 560,
#    'TotalConfirmed': 463888,
#    'NewDeaths': 0,
#    'TotalDeaths': 683,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '731352cb-1978-4497-b370-57b9352dd2e5',
#    'Country': 'Republic of Kosovo',
#    'CountryCode': 'XK',
#    'Slug': 'kosovo',
#    'NewConfirmed': 4,
#    'TotalConfirmed': 272129,
#    'NewDeaths': 0,
#    'TotalDeaths': 3201,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '49dd8e15-d259-45cf-a7e2-6565c3b7445e',
#    'Country': 'Romania',
#    'CountryCode': 'RO',
#    'Slug': 'romania',
#    'NewConfirmed': 619,
#    'TotalConfirmed': 3281666,
#    'NewDeaths': 14,
#    'TotalDeaths': 67145,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '337939dd-4e7b-408d-b150-478202897877',
#    'Country': 'Russian Federation',
#    'CountryCode': 'RU',
#    'Slug': 'russia',
#    'NewConfirmed': 10595,
#    'TotalConfirmed': 21031202,
#    'NewDeaths': 90,
#    'TotalDeaths': 381314,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '3c70b6bf-11f1-4cd8-8a0b-ee3e829f71a3',
#    'Country': 'Rwanda',
#    'CountryCode': 'RW',
#    'Slug': 'rwanda',
#    'NewConfirmed': 3,
#    'TotalConfirmed': 132533,
#    'NewDeaths': 0,
#    'TotalDeaths': 1467,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'f63c310d-adcc-40b2-93f0-bd687d16681d',
#    'Country': 'Saint Kitts and Nevis',
#    'CountryCode': 'KN',
#    'Slug': 'saint-kitts-and-nevis',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 6547,
#    'NewDeaths': 0,
#    'TotalDeaths': 46,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '3d79d277-2e9e-4786-a8f1-e6b62ef85d49',
#    'Country': 'Saint Lucia',
#    'CountryCode': 'LC',
#    'Slug': 'saint-lucia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 29550,
#    'NewDeaths': 0,
#    'TotalDeaths': 405,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '9d81438c-330b-4d51-9752-8fe42f4f11a3',
#    'Country': 'Saint Vincent and Grenadines',
#    'CountryCode': 'VC',
#    'Slug': 'saint-vincent-and-the-grenadines',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 9452,
#    'NewDeaths': 0,
#    'TotalDeaths': 116,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '7c5ec0fd-6a08-47a0-906e-e925ce72d42b',
#    'Country': 'Samoa',
#    'CountryCode': 'WS',
#    'Slug': 'samoa',
#    'NewConfirmed': 4,
#    'TotalConfirmed': 15946,
#    'NewDeaths': 0,
#    'TotalDeaths': 29,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '26b930b3-1c77-45bd-bec1-ecf3db78dd3a',
#    'Country': 'San Marino',
#    'CountryCode': 'SM',
#    'Slug': 'san-marino',
#    'NewConfirmed': 37,
#    'TotalConfirmed': 21400,
#    'NewDeaths': 0,
#    'TotalDeaths': 118,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '556cde14-b976-4dbe-92f8-e80e5b7704b0',
#    'Country': 'Sao Tome and Principe',
#    'CountryCode': 'ST',
#    'Slug': 'sao-tome-and-principe',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 6263,
#    'NewDeaths': 0,
#    'TotalDeaths': 77,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'ddd8d96f-d4c6-4ad6-97ca-366df8ba9875',
#    'Country': 'Saudi Arabia',
#    'CountryCode': 'SA',
#    'Slug': 'saudi-arabia',
#    'NewConfirmed': 247,
#    'TotalConfirmed': 819570,
#    'NewDeaths': 3,
#    'TotalDeaths': 9387,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'e5f5047e-08c1-4a65-be42-df2da7634cb1',
#    'Country': 'Senegal',
#    'CountryCode': 'SN',
#    'Slug': 'senegal',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 88630,
#    'NewDeaths': 0,
#    'TotalDeaths': 1968,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '722432dc-da04-4a9f-8b5b-6fb907b60cd2',
#    'Country': 'Serbia',
#    'CountryCode': 'RS',
#    'Slug': 'serbia',
#    'NewConfirmed': 1318,
#    'TotalConfirmed': 2392745,
#    'NewDeaths': 8,
#    'TotalDeaths': 17162,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'e405fba0-966d-4aa5-a199-43e2540f051f',
#    'Country': 'Seychelles',
#    'CountryCode': 'SC',
#    'Slug': 'seychelles',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 47141,
#    'NewDeaths': 0,
#    'TotalDeaths': 170,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '8572b0b3-a44b-4228-94c2-d2d5bcd36c8f',
#    'Country': 'Sierra Leone',
#    'CountryCode': 'SL',
#    'Slug': 'sierra-leone',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7752,
#    'NewDeaths': 0,
#    'TotalDeaths': 126,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '0655c71f-7a4f-4faa-9434-52552f03a469',
#    'Country': 'Singapore',
#    'CountryCode': 'SG',
#    'Slug': 'singapore',
#    'NewConfirmed': 8752,
#    'TotalConfirmed': 2037947,
#    'NewDeaths': 3,
#    'TotalDeaths': 1654,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'f8cee980-0c1d-4124-b175-8608ccb96f6d',
#    'Country': 'Slovakia',
#    'CountryCode': 'SK',
#    'Slug': 'slovakia',
#    'NewConfirmed': 670,
#    'TotalConfirmed': 2638637,
#    'NewDeaths': 7,
#    'TotalDeaths': 20530,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '7f63232c-d0e0-4853-906d-ccc0e75f7de5',
#    'Country': 'Slovenia',
#    'CountryCode': 'SI',
#    'Slug': 'slovenia',
#    'NewConfirmed': 1794,
#    'TotalConfirmed': 1220889,
#    'NewDeaths': 6,
#    'TotalDeaths': 6864,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '11366029-3957-4c95-8b8c-0c8a054b1da3',
#    'Country': 'Solomon Islands',
#    'CountryCode': 'SB',
#    'Slug': 'solomon-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 21544,
#    'NewDeaths': 0,
#    'TotalDeaths': 153,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '27c83762-8dcc-4072-b4b3-50a58c3aac07',
#    'Country': 'Somalia',
#    'CountryCode': 'SO',
#    'Slug': 'somalia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 27223,
#    'NewDeaths': 0,
#    'TotalDeaths': 1361,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'ba9bf4cf-4ed2-4d7a-a8c8-c4a60232f08f',
#    'Country': 'South Africa',
#    'CountryCode': 'ZA',
#    'Slug': 'south-africa',
#    'NewConfirmed': 424,
#    'TotalConfirmed': 4024553,
#    'NewDeaths': 0,
#    'TotalDeaths': 102246,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '97ac3f22-27fc-42d4-b943-3d52b613c1d6',
#    'Country': 'South Sudan',
#    'CountryCode': 'SS',
#    'Slug': 'south-sudan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 17823,
#    'NewDeaths': 0,
#    'TotalDeaths': 138,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '697ee80f-f807-41e9-8a1f-a9fcc4f76c91',
#    'Country': 'Spain',
#    'CountryCode': 'ES',
#    'Slug': 'spain',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 13462593,
#    'NewDeaths': 0,
#    'TotalDeaths': 114641,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '8307362c-9e94-4ea2-8016-27541b58f1a2',
#    'Country': 'Sri Lanka',
#    'CountryCode': 'LK',
#    'Slug': 'sri-lanka',
#    'NewConfirmed': 10,
#    'TotalConfirmed': 670952,
#    'NewDeaths': 2,
#    'TotalDeaths': 16772,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '26fa3c48-3c4f-4732-9450-b13430f35500',
#    'Country': 'Sudan',
#    'CountryCode': 'SD',
#    'Slug': 'sudan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 63449,
#    'NewDeaths': 1,
#    'TotalDeaths': 4965,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '69bd5bfe-dd79-4696-ad1f-20c823e97dc2',
#    'Country': 'Suriname',
#    'CountryCode': 'SR',
#    'Slug': 'suriname',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 81158,
#    'NewDeaths': 0,
#    'TotalDeaths': 1386,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'fa55a972-c4e0-49c8-bcf5-7cf25793e0e7',
#    'Country': 'Swaziland',
#    'CountryCode': 'SZ',
#    'Slug': 'swaziland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 73436,
#    'NewDeaths': 0,
#    'TotalDeaths': 1422,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '60b7f587-36f4-4963-bf80-ad824d26bff6',
#    'Country': 'Sweden',
#    'CountryCode': 'SE',
#    'Slug': 'sweden',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2604866,
#    'NewDeaths': 0,
#    'TotalDeaths': 20438,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '2fe48e3c-e1ab-49bc-a80b-92d1b87ce82f',
#    'Country': 'Switzerland',
#    'CountryCode': 'CH',
#    'Slug': 'switzerland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4164685,
#    'NewDeaths': 10,
#    'TotalDeaths': 14041,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '2fcea95a-92a3-44af-abe5-de01a8dd61f1',
#    'Country': 'Syrian Arab Republic (Syria)',
#    'CountryCode': 'SY',
#    'Slug': 'syria',
#    'NewConfirmed': 2,
#    'TotalConfirmed': 57340,
#    'NewDeaths': 0,
#    'TotalDeaths': 3163,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'd7f3be1f-98ca-40bf-8e75-fe5cfcb7bf43',
#    'Country': 'Taiwan, Republic of China',
#    'CountryCode': 'TW',
#    'Slug': 'taiwan',
#    'NewConfirmed': 44596,
#    'TotalConfirmed': 7302188,
#    'NewDeaths': 42,
#    'TotalDeaths': 12036,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '669bbc33-ed3e-47b7-8f6c-89ec71562587',
#    'Country': 'Tajikistan',
#    'CountryCode': 'TJ',
#    'Slug': 'tajikistan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 17786,
#    'NewDeaths': 0,
#    'TotalDeaths': 125,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '24f5532d-3a04-4ae4-83c2-c02f9921bea1',
#    'Country': 'Tanzania, United Republic of',
#    'CountryCode': 'TZ',
#    'Slug': 'tanzania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 39679,
#    'NewDeaths': 0,
#    'TotalDeaths': 845,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '0b3e4f30-2fc2-4888-a100-c8c1727b0730',
#    'Country': 'Thailand',
#    'CountryCode': 'TH',
#    'Slug': 'thailand',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4687281,
#    'NewDeaths': 0,
#    'TotalDeaths': 32882,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'c37436bc-1d8a-4fca-a732-d6be0fe886fd',
#    'Country': 'Timor-Leste',
#    'CountryCode': 'TL',
#    'Slug': 'timor-leste',
#    'NewConfirmed': 3,
#    'TotalConfirmed': 23291,
#    'NewDeaths': 0,
#    'TotalDeaths': 138,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'fb9ce617-3d07-4b52-96ed-19768459d524',
#    'Country': 'Togo',
#    'CountryCode': 'TG',
#    'Slug': 'togo',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 39261,
#    'NewDeaths': 0,
#    'TotalDeaths': 288,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'ee9a0c66-90cc-4394-b72d-ee6c7163989c',
#    'Country': 'Tonga',
#    'CountryCode': 'TO',
#    'Slug': 'tonga',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 16182,
#    'NewDeaths': 0,
#    'TotalDeaths': 12,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'f6b36eb6-939e-48b7-a795-1efe2843542a',
#    'Country': 'Trinidad and Tobago',
#    'CountryCode': 'TT',
#    'Slug': 'trinidad-and-tobago',
#    'NewConfirmed': 263,
#    'TotalConfirmed': 184524,
#    'NewDeaths': 6,
#    'TotalDeaths': 4241,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '6d84c35a-da68-4717-a9a1-1774a2b608df',
#    'Country': 'Tunisia',
#    'CountryCode': 'TN',
#    'Slug': 'tunisia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1146044,
#    'NewDeaths': 0,
#    'TotalDeaths': 29257,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '6a65e181-93a1-40e6-8a9d-72bfeb8c6c40',
#    'Country': 'Turkey',
#    'CountryCode': 'TR',
#    'Slug': 'turkey',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 16919638,
#    'NewDeaths': 0,
#    'TotalDeaths': 101203,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'a3957f50-da71-409c-8bd1-9e02e6579438',
#    'Country': 'Tuvalu',
#    'CountryCode': 'TV',
#    'Slug': 'tuvalu',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 20,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '815303fb-7e31-4a34-918a-44ee601179c8',
#    'Country': 'Uganda',
#    'CountryCode': 'UG',
#    'Slug': 'uganda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 169396,
#    'NewDeaths': 0,
#    'TotalDeaths': 3630,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'e935c4c0-f897-4b3d-a17d-6f828be38e58',
#    'Country': 'Ukraine',
#    'CountryCode': 'UA',
#    'Slug': 'ukraine',
#    'NewConfirmed': 61,
#    'TotalConfirmed': 5583231,
#    'NewDeaths': 2,
#    'TotalDeaths': 117681,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '1c456882-6fb0-483c-b393-7a6a71bd43b7',
#    'Country': 'United Arab Emirates',
#    'CountryCode': 'AE',
#    'Slug': 'united-arab-emirates',
#    'NewConfirmed': 312,
#    'TotalConfirmed': 1033770,
#    'NewDeaths': 0,
#    'TotalDeaths': 2347,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '03062ec1-f0ed-4d04-bd6d-8ff5540570bc',
#    'Country': 'United Kingdom',
#    'CountryCode': 'GB',
#    'Slug': 'united-kingdom',
#    'NewConfirmed': 177,
#    'TotalConfirmed': 24021973,
#    'NewDeaths': 0,
#    'TotalDeaths': 208678,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '41881db7-7961-486c-94ef-992d786e330c',
#    'Country': 'United States of America',
#    'CountryCode': 'US',
#    'Slug': 'united-states',
#    'NewConfirmed': 60137,
#    'TotalConfirmed': 97083662,
#    'NewDeaths': 746,
#    'TotalDeaths': 1066584,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '76795411-affa-41fc-b164-9148d3d92772',
#    'Country': 'Uruguay',
#    'CountryCode': 'UY',
#    'Slug': 'uruguay',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 988527,
#    'NewDeaths': 0,
#    'TotalDeaths': 7510,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '0cd7c686-e389-4295-a035-818df1967cee',
#    'Country': 'Uzbekistan',
#    'CountryCode': 'UZ',
#    'Slug': 'uzbekistan',
#    'NewConfirmed': 3,
#    'TotalConfirmed': 244424,
#    'NewDeaths': 0,
#    'TotalDeaths': 1637,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'b18aa221-509f-4126-96bf-e810a55e1822',
#    'Country': 'Vanuatu',
#    'CountryCode': 'VU',
#    'Slug': 'vanuatu',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 11976,
#    'NewDeaths': 0,
#    'TotalDeaths': 14,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '563c05d6-aa54-4170-9b9b-8432df6b8704',
#    'Country': 'Venezuela (Bolivarian Republic)',
#    'CountryCode': 'VE',
#    'Slug': 'venezuela',
#    'NewConfirmed': 92,
#    'TotalConfirmed': 545469,
#    'NewDeaths': 0,
#    'TotalDeaths': 5820,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'e7d97897-9297-4b0f-846e-ac47d9af268f',
#    'Country': 'Viet Nam',
#    'CountryCode': 'VN',
#    'Slug': 'vietnam',
#    'NewConfirmed': 1337,
#    'TotalConfirmed': 11495231,
#    'NewDeaths': 1,
#    'TotalDeaths': 43159,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '69b2855a-ebed-43a7-9e54-bc8e02262810',
#    'Country': 'Yemen',
#    'CountryCode': 'YE',
#    'Slug': 'yemen',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 11939,
#    'NewDeaths': 0,
#    'TotalDeaths': 2158,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': 'e1d8f70a-df14-4912-94e4-5e33a4580362',
#    'Country': 'Zambia',
#    'CountryCode': 'ZM',
#    'Slug': 'zambia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 333644,
#    'NewDeaths': 0,
#    'TotalDeaths': 4017,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}},
#   {'ID': '67427123-6e14-4a7d-9266-4d04f67b9a37',
#    'Country': 'Zimbabwe',
#    'CountryCode': 'ZW',
#    'Slug': 'zimbabwe',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 257893,
#    'NewDeaths': 0,
#    'TotalDeaths': 5606,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-10-21T03:07:56.806Z',
#    'Premium': {}}],
#  'Date': '2022-10-21T03:07:56.806Z'}

# %%
type(response_info)
# Out:
# dict

# %%
response_info['Countries']
# Out:
# [{'ID': '0272026c-f9eb-4e3d-a173-31911cffe89c',
#   'Country': 'Afghanistan',
#   'CountryCode': 'AF',
#   'Slug': 'afghanistan',
#   'NewConfirmed': 54,
#   'TotalConfirmed': 201557,
#   'NewDeaths': 0,
#   'TotalDeaths': 7812,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '210b9b48-3bd2-45f5-8e95-8953bf850553',
#   'Country': 'Albania',
#   'CountryCode': 'AL',
#   'Slug': 'albania',
#   'NewConfirmed': 28,
#   'TotalConfirmed': 332701,
#   'NewDeaths': 0,
#   'TotalDeaths': 3592,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '63208d7a-cd4d-4d1e-9301-4e475c33c012',
#   'Country': 'Algeria',
#   'CountryCode': 'DZ',
#   'Slug': 'algeria',
#   'NewConfirmed': 2,
#   'TotalConfirmed': 270768,
#   'NewDeaths': 0,
#   'TotalDeaths': 6881,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'f479fc66-7c0e-47fc-bfd9-5ac7fd56b77b',
#   'Country': 'Andorra',
#   'CountryCode': 'AD',
#   'Slug': 'andorra',
#   'NewConfirmed': 83,
#   'TotalConfirmed': 46449,
#   'NewDeaths': 0,
#   'TotalDeaths': 155,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '6e86a804-570c-4d17-b482-ce7f497300ba',
#   'Country': 'Angola',
#   'CountryCode': 'AO',
#   'Slug': 'angola',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 103131,
#   'NewDeaths': 0,
#   'TotalDeaths': 1917,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'ed8fd15f-b55c-4c64-b841-4ee7a4625dbb',
#   'Country': 'Antarctica',
#   'CountryCode': 'AQ',
#   'Slug': 'antarctica',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 11,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '965286c8-794c-45d2-9f10-4e4c08cf67b6',
#   'Country': 'Antigua and Barbuda',
#   'CountryCode': 'AG',
#   'Slug': 'antigua-and-barbuda',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 9106,
#   'NewDeaths': 0,
#   'TotalDeaths': 146,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '6f77f961-d567-407c-a962-94c923b916b5',
#   'Country': 'Argentina',
#   'CountryCode': 'AR',
#   'Slug': 'argentina',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 9715464,
#   'NewDeaths': 0,
#   'TotalDeaths': 129970,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '63bee3f7-a3b4-450c-a9a2-85df67701820',
#   'Country': 'Armenia',
#   'CountryCode': 'AM',
#   'Slug': 'armenia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 444869,
#   'NewDeaths': 0,
#   'TotalDeaths': 8706,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '2815ee56-5b2d-4955-993d-1df95fafd311',
#   'Country': 'Australia',
#   'CountryCode': 'AU',
#   'Slug': 'australia',
#   'NewConfirmed': 1093,
#   'TotalConfirmed': 10313911,
#   'NewDeaths': 6,
#   'TotalDeaths': 15496,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'a122bd98-b39c-4675-8f7c-49f8c3609273',
#   'Country': 'Austria',
#   'CountryCode': 'AT',
#   'Slug': 'austria',
#   'NewConfirmed': 13711,
#   'TotalConfirmed': 5369885,
#   'NewDeaths': 10,
#   'TotalDeaths': 20953,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'f0cb657a-bca2-4d88-8f11-9154d152ad9c',
#   'Country': 'Azerbaijan',
#   'CountryCode': 'AZ',
#   'Slug': 'azerbaijan',
#   'NewConfirmed': 65,
#   'TotalConfirmed': 822751,
#   'NewDeaths': 0,
#   'TotalDeaths': 9935,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '6b4565b8-bef6-4940-acd9-3fcea5302a90',
#   'Country': 'Bahamas',
#   'CountryCode': 'BS',
#   'Slug': 'bahamas',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 37334,
#   'NewDeaths': 0,
#   'TotalDeaths': 833,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'd3274c0f-13de-49a7-b0c9-2300a4f1e258',
#   'Country': 'Bahrain',
#   'CountryCode': 'BH',
#   'Slug': 'bahrain',
#   'NewConfirmed': 312,
#   'TotalConfirmed': 686629,
#   'NewDeaths': 0,
#   'TotalDeaths': 1523,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '62c6a242-8aac-4c86-83e7-3e63a62a11bd',
#   'Country': 'Bangladesh',
#   'CountryCode': 'BD',
#   'Slug': 'bangladesh',
#   'NewConfirmed': 300,
#   'TotalConfirmed': 2033419,
#   'NewDeaths': 2,
#   'TotalDeaths': 29410,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'bcd187e5-4727-47b8-8f3e-647d8965f3a4',
#   'Country': 'Barbados',
#   'CountryCode': 'BB',
#   'Slug': 'barbados',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 103014,
#   'NewDeaths': 0,
#   'TotalDeaths': 560,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'c7e268d2-3c8c-4e6a-a492-482339020e56',
#   'Country': 'Belarus',
#   'CountryCode': 'BY',
#   'Slug': 'belarus',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 994037,
#   'NewDeaths': 0,
#   'TotalDeaths': 7118,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '03a8cd2c-65df-431b-b711-e6d39f90ddba',
#   'Country': 'Belgium',
#   'CountryCode': 'BE',
#   'Slug': 'belgium',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 4594338,
#   'NewDeaths': 0,
#   'TotalDeaths': 32810,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '765c48ff-abf6-478f-90ad-c8a15234cffe',
#   'Country': 'Belize',
#   'CountryCode': 'BZ',
#   'Slug': 'belize',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 68926,
#   'NewDeaths': 0,
#   'TotalDeaths': 687,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'f9265ea6-35c7-46a1-9448-c44dc7759889',
#   'Country': 'Benin',
#   'CountryCode': 'BJ',
#   'Slug': 'benin',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 27782,
#   'NewDeaths': 0,
#   'TotalDeaths': 163,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'bfcdee2d-03db-424e-ac5f-2ca1fbbdde26',
#   'Country': 'Bhutan',
#   'CountryCode': 'BT',
#   'Slug': 'bhutan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 62248,
#   'NewDeaths': 0,
#   'TotalDeaths': 21,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '0d9e2cf5-8df8-4602-8af6-c8db4f444dde',
#   'Country': 'Bolivia',
#   'CountryCode': 'BO',
#   'Slug': 'bolivia',
#   'NewConfirmed': 86,
#   'TotalConfirmed': 1109123,
#   'NewDeaths': 0,
#   'TotalDeaths': 22237,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '9e80547d-ce8f-40c8-8cb3-4b5c5a95e9e3',
#   'Country': 'Bosnia and Herzegovina',
#   'CountryCode': 'BA',
#   'Slug': 'bosnia-and-herzegovina',
#   'NewConfirmed': 40,
#   'TotalConfirmed': 399584,
#   'NewDeaths': 1,
#   'TotalDeaths': 16161,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'c40f52fb-a031-45b5-87ee-c5d197f5e179',
#   'Country': 'Botswana',
#   'CountryCode': 'BW',
#   'Slug': 'botswana',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 326344,
#   'NewDeaths': 0,
#   'TotalDeaths': 2790,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '8e03dc8c-2655-4e0b-8eef-71d2a1ee1ae5',
#   'Country': 'Brazil',
#   'CountryCode': 'BR',
#   'Slug': 'brazil',
#   'NewConfirmed': 24858,
#   'TotalConfirmed': 34771320,
#   'NewDeaths': 279,
#   'TotalDeaths': 687423,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '901f4993-465b-4b8a-9a0c-2c01df64262f',
#   'Country': 'Brunei Darussalam',
#   'CountryCode': 'BN',
#   'Slug': 'brunei',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 234582,
#   'NewDeaths': 0,
#   'TotalDeaths': 225,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'dd667310-c222-4444-b2e0-8aedc396559c',
#   'Country': 'Bulgaria',
#   'CountryCode': 'BG',
#   'Slug': 'bulgaria',
#   'NewConfirmed': 630,
#   'TotalConfirmed': 1272645,
#   'NewDeaths': 11,
#   'TotalDeaths': 37812,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '65bca9e6-78d7-4412-b462-1c452911ae57',
#   'Country': 'Burkina Faso',
#   'CountryCode': 'BF',
#   'Slug': 'burkina-faso',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 21631,
#   'NewDeaths': 0,
#   'TotalDeaths': 387,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '479f517a-0cbb-4164-9275-c121a639c39b',
#   'Country': 'Burundi',
#   'CountryCode': 'BI',
#   'Slug': 'burundi',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 50372,
#   'NewDeaths': 0,
#   'TotalDeaths': 38,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'be6c3b9a-552a-4fdd-a37e-bf927cb74e86',
#   'Country': 'Cambodia',
#   'CountryCode': 'KH',
#   'Slug': 'cambodia',
#   'NewConfirmed': 1,
#   'TotalConfirmed': 137976,
#   'NewDeaths': 0,
#   'TotalDeaths': 3056,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '42286f65-0715-40cd-a413-42fe631e293c',
#   'Country': 'Cameroon',
#   'CountryCode': 'CM',
#   'Slug': 'cameroon',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 121652,
#   'NewDeaths': 0,
#   'TotalDeaths': 1935,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'dcc2efa4-8757-4111-8906-d1c051aa4c8b',
#   'Country': 'Canada',
#   'CountryCode': 'CA',
#   'Slug': 'canada',
#   'NewConfirmed': 1107,
#   'TotalConfirmed': 3721413,
#   'NewDeaths': 10,
#   'TotalDeaths': 41036,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '1a32d3b0-5f11-41fd-bfe6-a95646c214bf',
#   'Country': 'Cape Verde',
#   'CountryCode': 'CV',
#   'Slug': 'cape-verde',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 62397,
#   'NewDeaths': 0,
#   'TotalDeaths': 410,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '7d46d507-d935-403b-810a-e0e2fe999c1e',
#   'Country': 'Central African Republic',
#   'CountryCode': 'CF',
#   'Slug': 'central-african-republic',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 15151,
#   'NewDeaths': 0,
#   'TotalDeaths': 113,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '806ea21a-cd55-429c-a7b8-2344c569182e',
#   'Country': 'Chad',
#   'CountryCode': 'TD',
#   'Slug': 'chad',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 7613,
#   'NewDeaths': 0,
#   'TotalDeaths': 193,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '53feca91-67aa-4973-b56b-884cf801f680',
#   'Country': 'Chile',
#   'CountryCode': 'CL',
#   'Slug': 'chile',
#   'NewConfirmed': 5743,
#   'TotalConfirmed': 4690513,
#   'NewDeaths': 4,
#   'TotalDeaths': 61459,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '8534e328-08e7-4b51-ab21-72c3760c4458',
#   'Country': 'China',
#   'CountryCode': 'CN',
#   'Slug': 'china',
#   'NewConfirmed': 5335,
#   'TotalConfirmed': 2110808,
#   'NewDeaths': 12,
#   'TotalDeaths': 15529,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'fe562f03-685d-49a9-93cd-c19f37783c6d',
#   'Country': 'Colombia',
#   'CountryCode': 'CO',
#   'Slug': 'colombia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 6308558,
#   'NewDeaths': 0,
#   'TotalDeaths': 141820,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '514ea4ab-b601-45e6-a376-e92054ecc610',
#   'Country': 'Comoros',
#   'CountryCode': 'KM',
#   'Slug': 'comoros',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 8481,
#   'NewDeaths': 0,
#   'TotalDeaths': 161,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '7db86baa-a2fc-4dd9-996a-bef4203da289',
#   'Country': 'Congo (Brazzaville)',
#   'CountryCode': 'CG',
#   'Slug': 'congo-brazzaville',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 24837,
#   'NewDeaths': 0,
#   'TotalDeaths': 386,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'cfd33788-a19b-400d-b9c8-e45a4e38fad8',
#   'Country': 'Congo (Kinshasa)',
#   'CountryCode': 'CD',
#   'Slug': 'congo-kinshasa',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 92972,
#   'NewDeaths': 0,
#   'TotalDeaths': 1444,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'de052797-903b-4712-b85a-ce4303e1caea',
#   'Country': 'Costa Rica',
#   'CountryCode': 'CR',
#   'Slug': 'costa-rica',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1130568,
#   'NewDeaths': 0,
#   'TotalDeaths': 8982,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '799b502d-f01b-4b0e-adab-2ce4694162ad',
#   'Country': 'Croatia',
#   'CountryCode': 'HR',
#   'Slug': 'croatia',
#   'NewConfirmed': 755,
#   'TotalConfirmed': 1242909,
#   'NewDeaths': 7,
#   'TotalDeaths': 17046,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '90401c10-77eb-411c-a2ab-38ff0a5f5044',
#   'Country': 'Cuba',
#   'CountryCode': 'CU',
#   'Slug': 'cuba',
#   'NewConfirmed': 3,
#   'TotalConfirmed': 1111263,
#   'NewDeaths': 0,
#   'TotalDeaths': 8530,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'df145ff6-2109-48bd-892e-d4b1cbc7b629',
#   'Country': 'Cyprus',
#   'CountryCode': 'CY',
#   'Slug': 'cyprus',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 593542,
#   'NewDeaths': 0,
#   'TotalDeaths': 1189,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'bfc28bcf-b158-4610-87d1-b7f600b2d969',
#   'Country': 'Czech Republic',
#   'CountryCode': 'CZ',
#   'Slug': 'czech-republic',
#   'NewConfirmed': 1800,
#   'TotalConfirmed': 4147736,
#   'NewDeaths': 27,
#   'TotalDeaths': 41454,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '9e86a444-214f-45d1-9d8a-98a7a659ff31',
#   'Country': "Côte d'Ivoire",
#   'CountryCode': 'CI',
#   'Slug': 'cote-divoire',
#   'NewConfirmed': 55,
#   'TotalConfirmed': 87657,
#   'NewDeaths': 0,
#   'TotalDeaths': 827,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'bfa0889f-9ceb-4358-a489-e8e8b1d95b24',
#   'Country': 'Denmark',
#   'CountryCode': 'DK',
#   'Slug': 'denmark',
#   'NewConfirmed': 1444,
#   'TotalConfirmed': 3370464,
#   'NewDeaths': 16,
#   'TotalDeaths': 7271,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'c71e0679-b5a4-4f57-94cd-f7da4992d860',
#   'Country': 'Djibouti',
#   'CountryCode': 'DJ',
#   'Slug': 'djibouti',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 15690,
#   'NewDeaths': 0,
#   'TotalDeaths': 189,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '4ab45482-4a9b-42d7-8245-d8bcb28100c4',
#   'Country': 'Dominica',
#   'CountryCode': 'DM',
#   'Slug': 'dominica',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 15760,
#   'NewDeaths': 0,
#   'TotalDeaths': 74,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'c46e5021-84d0-4446-8389-9446cbdc5d6a',
#   'Country': 'Dominican Republic',
#   'CountryCode': 'DO',
#   'Slug': 'dominican-republic',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 647205,
#   'NewDeaths': 0,
#   'TotalDeaths': 4384,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'b48d29b4-5752-4845-af71-a867d5cffa7c',
#   'Country': 'Ecuador',
#   'CountryCode': 'EC',
#   'Slug': 'ecuador',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1006922,
#   'NewDeaths': 0,
#   'TotalDeaths': 35904,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'cdcc192f-2755-4763-b6c9-af35cfbb7184',
#   'Country': 'Egypt',
#   'CountryCode': 'EG',
#   'Slug': 'egypt',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 515645,
#   'NewDeaths': 1,
#   'TotalDeaths': 24798,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '8bc9b38a-7d79-4545-ba6b-2ecf3ecf3802',
#   'Country': 'El Salvador',
#   'CountryCode': 'SV',
#   'Slug': 'el-salvador',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 201785,
#   'NewDeaths': 0,
#   'TotalDeaths': 4230,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '53fe4d7a-c7cd-48a0-926a-90d009d7e1d2',
#   'Country': 'Equatorial Guinea',
#   'CountryCode': 'GQ',
#   'Slug': 'equatorial-guinea',
#   'NewConfirmed': 14,
#   'TotalConfirmed': 17131,
#   'NewDeaths': 0,
#   'TotalDeaths': 183,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '2d187a1f-0b34-40df-aeb4-7968baa18112',
#   'Country': 'Eritrea',
#   'CountryCode': 'ER',
#   'Slug': 'eritrea',
#   'NewConfirmed': 3,
#   'TotalConfirmed': 10185,
#   'NewDeaths': 0,
#   'TotalDeaths': 103,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '8bc650be-6519-44dc-bf97-3b0d8805cc23',
#   'Country': 'Estonia',
#   'CountryCode': 'EE',
#   'Slug': 'estonia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 605622,
#   'NewDeaths': 0,
#   'TotalDeaths': 2729,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'e658bada-4d72-413e-b2fd-020f5f1563ff',
#   'Country': 'Ethiopia',
#   'CountryCode': 'ET',
#   'Slug': 'ethiopia',
#   'NewConfirmed': 15,
#   'TotalConfirmed': 493818,
#   'NewDeaths': 0,
#   'TotalDeaths': 7572,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'bea63fed-c31e-46d1-8f43-778c69831e80',
#   'Country': 'Fiji',
#   'CountryCode': 'FJ',
#   'Slug': 'fiji',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 68248,
#   'NewDeaths': 0,
#   'TotalDeaths': 878,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '349d8b03-2512-4c7c-801c-6de5fa164d1b',
#   'Country': 'Finland',
#   'CountryCode': 'FI',
#   'Slug': 'finland',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1323455,
#   'NewDeaths': 0,
#   'TotalDeaths': 6242,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'acde5dd5-b5c6-42c9-8896-3a2fcd6d9fca',
#   'Country': 'France',
#   'CountryCode': 'FR',
#   'Slug': 'france',
#   'NewConfirmed': 63062,
#   'TotalConfirmed': 36636069,
#   'NewDeaths': 106,
#   'TotalDeaths': 157227,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '6bdb26bc-df10-4c66-812d-9b0a4e0093ad',
#   'Country': 'Gabon',
#   'CountryCode': 'GA',
#   'Slug': 'gabon',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 48810,
#   'NewDeaths': 0,
#   'TotalDeaths': 306,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'ff1edab4-2f8b-4d8f-89e7-eba7ed635c81',
#   'Country': 'Gambia',
#   'CountryCode': 'GM',
#   'Slug': 'gambia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 12508,
#   'NewDeaths': 0,
#   'TotalDeaths': 372,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '9499af82-bf42-49ba-b913-b0361f7acd50',
#   'Country': 'Georgia',
#   'CountryCode': 'GE',
#   'Slug': 'georgia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1780691,
#   'NewDeaths': 0,
#   'TotalDeaths': 16900,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'fc40f677-d067-4a18-8b43-3d6cb7bcb86a',
#   'Country': 'Germany',
#   'CountryCode': 'DE',
#   'Slug': 'germany',
#   'NewConfirmed': 116806,
#   'TotalConfirmed': 35005769,
#   'NewDeaths': 223,
#   'TotalDeaths': 152100,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '12376334-f3f9-4c4a-8ea5-340671502a40',
#   'Country': 'Ghana',
#   'CountryCode': 'GH',
#   'Slug': 'ghana',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 170321,
#   'NewDeaths': 0,
#   'TotalDeaths': 1460,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '3728a57c-3597-462e-8a8a-ba2532108276',
#   'Country': 'Greece',
#   'CountryCode': 'GR',
#   'Slug': 'greece',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 5081981,
#   'NewDeaths': 0,
#   'TotalDeaths': 33426,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'bbe379d5-c5cb-49d8-aa3c-a18e5010fe60',
#   'Country': 'Grenada',
#   'CountryCode': 'GD',
#   'Slug': 'grenada',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 19584,
#   'NewDeaths': 0,
#   'TotalDeaths': 237,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '401812cd-91ca-41ba-beb8-d38bc91d733c',
#   'Country': 'Guatemala',
#   'CountryCode': 'GT',
#   'Slug': 'guatemala',
#   'NewConfirmed': 698,
#   'TotalConfirmed': 1134947,
#   'NewDeaths': 2,
#   'TotalDeaths': 19861,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '9013f2ff-3818-4e3e-862e-d224e4552df5',
#   'Country': 'Guinea',
#   'CountryCode': 'GN',
#   'Slug': 'guinea',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 37999,
#   'NewDeaths': 0,
#   'TotalDeaths': 456,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'b6bc3da1-1978-49cb-8efe-55158b029b92',
#   'Country': 'Guinea-Bissau',
#   'CountryCode': 'GW',
#   'Slug': 'guinea-bissau',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 8831,
#   'NewDeaths': 0,
#   'TotalDeaths': 176,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'cc5f2928-90a3-435f-a86f-8fae0a420dfc',
#   'Country': 'Guyana',
#   'CountryCode': 'GY',
#   'Slug': 'guyana',
#   'NewConfirmed': 14,
#   'TotalConfirmed': 71418,
#   'NewDeaths': 0,
#   'TotalDeaths': 1281,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'ebeeca17-f8d8-47ce-a128-80bf73244573',
#   'Country': 'Haiti',
#   'CountryCode': 'HT',
#   'Slug': 'haiti',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 33764,
#   'NewDeaths': 0,
#   'TotalDeaths': 857,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'a1d5a1b9-0413-47b3-9d4d-77511d910df0',
#   'Country': 'Holy See (Vatican City State)',
#   'CountryCode': 'VA',
#   'Slug': 'holy-see-vatican-city-state',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 29,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'cff9caf4-f45c-43d8-b7c6-59513ab3b8f1',
#   'Country': 'Honduras',
#   'CountryCode': 'HN',
#   'Slug': 'honduras',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 456886,
#   'NewDeaths': 0,
#   'TotalDeaths': 11007,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'abac5b43-2bbf-4b5c-97f1-65dfa8fb81ea',
#   'Country': 'Hungary',
#   'CountryCode': 'HU',
#   'Slug': 'hungary',
#   'NewConfirmed': 11947,
#   'TotalConfirmed': 2132490,
#   'NewDeaths': 118,
#   'TotalDeaths': 47798,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'f8724241-d81f-4ddc-8406-a6e4c0012b4f',
#   'Country': 'Iceland',
#   'CountryCode': 'IS',
#   'Slug': 'iceland',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 206134,
#   'NewDeaths': 0,
#   'TotalDeaths': 213,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '5d63c4cc-c1c9-4e7f-a0c2-9962c7c82ed6',
#   'Country': 'India',
#   'CountryCode': 'IN',
#   'Slug': 'india',
#   'NewConfirmed': 2141,
#   'TotalConfirmed': 44636517,
#   'NewDeaths': 20,
#   'TotalDeaths': 528943,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'ef21e1af-037e-4ecc-b957-8b262b4cf0ee',
#   'Country': 'Indonesia',
#   'CountryCode': 'ID',
#   'Slug': 'indonesia',
#   'NewConfirmed': 2390,
#   'TotalConfirmed': 6462655,
#   'NewDeaths': 16,
#   'TotalDeaths': 158361,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'aaf06eac-789d-4bc4-a895-29978f2bed6d',
#   'Country': 'Iran, Islamic Republic of',
#   'CountryCode': 'IR',
#   'Slug': 'iran',
#   'NewConfirmed': 345,
#   'TotalConfirmed': 7555355,
#   'NewDeaths': 4,
#   'TotalDeaths': 144531,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '30183f51-e487-41cc-aa26-4c1673edba54',
#   'Country': 'Iraq',
#   'CountryCode': 'IQ',
#   'Slug': 'iraq',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 2460868,
#   'NewDeaths': 0,
#   'TotalDeaths': 25356,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '7972e43d-a16c-418b-bc7d-46cc4f3b184b',
#   'Country': 'Ireland',
#   'CountryCode': 'IE',
#   'Slug': 'ireland',
#   'NewConfirmed': 2076,
#   'TotalConfirmed': 1670377,
#   'NewDeaths': 22,
#   'TotalDeaths': 8010,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'bdf0c870-ed52-4fef-b0f5-49eea34b18e0',
#   'Country': 'Israel',
#   'CountryCode': 'IL',
#   'Slug': 'israel',
#   'NewConfirmed': 971,
#   'TotalConfirmed': 4675027,
#   'NewDeaths': 0,
#   'TotalDeaths': 11728,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '08e7882d-e32f-43bc-9008-da85f03c896b',
#   'Country': 'Italy',
#   'CountryCode': 'IT',
#   'Slug': 'italy',
#   'NewConfirmed': 41703,
#   'TotalConfirmed': 23214073,
#   'NewDeaths': 81,
#   'TotalDeaths': 178275,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'cdf59560-35ae-4273-9014-149218b8f88d',
#   'Country': 'Jamaica',
#   'CountryCode': 'JM',
#   'Slug': 'jamaica',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 151931,
#   'NewDeaths': 0,
#   'TotalDeaths': 3320,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '3ed38fe6-4346-4fd7-beaa-9bd4330810fc',
#   'Country': 'Japan',
#   'CountryCode': 'JP',
#   'Slug': 'japan',
#   'NewConfirmed': 43555,
#   'TotalConfirmed': 21887525,
#   'NewDeaths': 68,
#   'TotalDeaths': 46120,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'dff74b87-28aa-4ceb-8343-095d4b499803',
#   'Country': 'Jordan',
#   'CountryCode': 'JO',
#   'Slug': 'jordan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1746997,
#   'NewDeaths': 0,
#   'TotalDeaths': 14122,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'e1cac802-cc37-4c0a-8154-bd6ac3ab9c56',
#   'Country': 'Kazakhstan',
#   'CountryCode': 'KZ',
#   'Slug': 'kazakhstan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1484400,
#   'NewDeaths': 0,
#   'TotalDeaths': 19052,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'cb960cca-6f46-405c-9cbb-a8ec39223141',
#   'Country': 'Kenya',
#   'CountryCode': 'KE',
#   'Slug': 'kenya',
#   'NewConfirmed': 31,
#   'TotalConfirmed': 338678,
#   'NewDeaths': 0,
#   'TotalDeaths': 5678,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '1c93ff84-1017-4d2c-bad4-7d85508f4097',
#   'Country': 'Kiribati',
#   'CountryCode': 'KI',
#   'Slug': 'kiribati',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 3430,
#   'NewDeaths': 0,
#   'TotalDeaths': 13,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'ee3386e7-d9a0-4964-8015-0c22e07e38bb',
#   'Country': 'Korea (North)',
#   'CountryCode': 'KP',
#   'Slug': 'korea-north',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1,
#   'NewDeaths': 0,
#   'TotalDeaths': 6,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '534acb8f-a7fe-4511-bbcb-57f5363921a2',
#   'Country': 'Korea (South)',
#   'CountryCode': 'KR',
#   'Slug': 'korea-south',
#   'NewConfirmed': 25369,
#   'TotalConfirmed': 25219546,
#   'NewDeaths': 23,
#   'TotalDeaths': 28922,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '59bcde27-444b-46e5-a4fe-5a7f56da583f',
#   'Country': 'Kuwait',
#   'CountryCode': 'KW',
#   'Slug': 'kuwait',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 661335,
#   'NewDeaths': 0,
#   'TotalDeaths': 2565,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '1a42303a-6eab-4bad-8c58-7d18cc6826b9',
#   'Country': 'Kyrgyzstan',
#   'CountryCode': 'KG',
#   'Slug': 'kyrgyzstan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 206334,
#   'NewDeaths': 0,
#   'TotalDeaths': 2991,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'ce812a55-898e-4a67-8da1-6662620b11df',
#   'Country': 'Lao PDR',
#   'CountryCode': 'LA',
#   'Slug': 'lao-pdr',
#   'NewConfirmed': 42,
#   'TotalConfirmed': 216158,
#   'NewDeaths': 0,
#   'TotalDeaths': 758,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '3a647319-1b60-4ed5-a38b-ca777c6f500e',
#   'Country': 'Latvia',
#   'CountryCode': 'LV',
#   'Slug': 'latvia',
#   'NewConfirmed': 918,
#   'TotalConfirmed': 946092,
#   'NewDeaths': 0,
#   'TotalDeaths': 6036,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'b3ff12cc-7c18-4ae5-92a4-5e61dadf92e5',
#   'Country': 'Lebanon',
#   'CountryCode': 'LB',
#   'Slug': 'lebanon',
#   'NewConfirmed': 832,
#   'TotalConfirmed': 1217831,
#   'NewDeaths': 8,
#   'TotalDeaths': 10696,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '412e118b-9e52-43d3-b5ea-62e540a121b1',
#   'Country': 'Lesotho',
#   'CountryCode': 'LS',
#   'Slug': 'lesotho',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 34490,
#   'NewDeaths': 0,
#   'TotalDeaths': 706,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'ff76ae2a-7339-447c-b6df-9eea52805b14',
#   'Country': 'Liberia',
#   'CountryCode': 'LR',
#   'Slug': 'liberia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 7988,
#   'NewDeaths': 0,
#   'TotalDeaths': 294,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '22ee8bc4-5407-46f4-b09d-0a072f592025',
#   'Country': 'Libya',
#   'CountryCode': 'LY',
#   'Slug': 'libya',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 507024,
#   'NewDeaths': 0,
#   'TotalDeaths': 6437,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '7c38c3cb-5665-41da-9cdf-ccc81498cdb0',
#   'Country': 'Liechtenstein',
#   'CountryCode': 'LI',
#   'Slug': 'liechtenstein',
#   'NewConfirmed': 31,
#   'TotalConfirmed': 20465,
#   'NewDeaths': 0,
#   'TotalDeaths': 86,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '2855f54b-15cb-447b-8038-879148c5f694',
#   'Country': 'Lithuania',
#   'CountryCode': 'LT',
#   'Slug': 'lithuania',
#   'NewConfirmed': 756,
#   'TotalConfirmed': 1263538,
#   'NewDeaths': 0,
#   'TotalDeaths': 9369,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'b8ef5ac3-3e92-446d-a668-748b6668d4d2',
#   'Country': 'Luxembourg',
#   'CountryCode': 'LU',
#   'Slug': 'luxembourg',
#   'NewConfirmed': 375,
#   'TotalConfirmed': 299022,
#   'NewDeaths': 0,
#   'TotalDeaths': 1140,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'bc2c7d1e-9aed-4798-88ff-2f27586b992e',
#   'Country': 'Macedonia, Republic of',
#   'CountryCode': 'MK',
#   'Slug': 'macedonia',
#   'NewConfirmed': 102,
#   'TotalConfirmed': 343824,
#   'NewDeaths': 2,
#   'TotalDeaths': 9556,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '44b48fd7-a3d6-4234-81da-05c13aaac651',
#   'Country': 'Madagascar',
#   'CountryCode': 'MG',
#   'Slug': 'madagascar',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 66687,
#   'NewDeaths': 0,
#   'TotalDeaths': 1410,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '3c037b3c-a368-4cf6-a7b5-19ce80eb0bbb',
#   'Country': 'Malawi',
#   'CountryCode': 'MW',
#   'Slug': 'malawi',
#   'NewConfirmed': 3,
#   'TotalConfirmed': 88064,
#   'NewDeaths': 0,
#   'TotalDeaths': 2683,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '61dcc3bf-95b8-453c-9511-0fd5fa9853b7',
#   'Country': 'Malaysia',
#   'CountryCode': 'MY',
#   'Slug': 'malaysia',
#   'NewConfirmed': 2295,
#   'TotalConfirmed': 4872570,
#   'NewDeaths': 3,
#   'TotalDeaths': 36429,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '872565da-e4cd-4798-9311-754a482eb870',
#   'Country': 'Maldives',
#   'CountryCode': 'MV',
#   'Slug': 'maldives',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 185194,
#   'NewDeaths': 0,
#   'TotalDeaths': 308,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'eb4e38ca-8a05-4627-a812-953e5e8d8cf4',
#   'Country': 'Mali',
#   'CountryCode': 'ML',
#   'Slug': 'mali',
#   'NewConfirmed': 1,
#   'TotalConfirmed': 32712,
#   'NewDeaths': 0,
#   'TotalDeaths': 742,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '6077ed21-ed8f-4e68-b23f-37711291ca0b',
#   'Country': 'Malta',
#   'CountryCode': 'MT',
#   'Slug': 'malta',
#   'NewConfirmed': 31,
#   'TotalConfirmed': 115103,
#   'NewDeaths': 0,
#   'TotalDeaths': 806,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'c56e5030-a205-4db6-b258-d0e1c28f2759',
#   'Country': 'Marshall Islands',
#   'CountryCode': 'MH',
#   'Slug': 'marshall-islands',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 15389,
#   'NewDeaths': 0,
#   'TotalDeaths': 17,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '636a5ea6-f4e8-4dcb-aec3-85812f5ccee4',
#   'Country': 'Mauritania',
#   'CountryCode': 'MR',
#   'Slug': 'mauritania',
#   'NewConfirmed': 31,
#   'TotalConfirmed': 63194,
#   'NewDeaths': 0,
#   'TotalDeaths': 995,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '0853a5fd-c524-4526-bab3-1571bfb67624',
#   'Country': 'Mauritius',
#   'CountryCode': 'MU',
#   'Slug': 'mauritius',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 263780,
#   'NewDeaths': 0,
#   'TotalDeaths': 1032,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'bdc34b71-ac6e-48ed-9e70-d931e19df352',
#   'Country': 'Mexico',
#   'CountryCode': 'MX',
#   'Slug': 'mexico',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 7103339,
#   'NewDeaths': 0,
#   'TotalDeaths': 330279,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'eb42150a-2f20-4d71-ae50-c9a90008ab49',
#   'Country': 'Micronesia, Federated States of',
#   'CountryCode': 'FM',
#   'Slug': 'micronesia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 21815,
#   'NewDeaths': 0,
#   'TotalDeaths': 55,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'fb14a687-eb71-4c0b-9226-a68767104a07',
#   'Country': 'Moldova',
#   'CountryCode': 'MD',
#   'Slug': 'moldova',
#   'NewConfirmed': 623,
#   'TotalConfirmed': 592535,
#   'NewDeaths': 9,
#   'TotalDeaths': 11879,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '88849eb5-fba4-430f-b70c-4667ab47b082',
#   'Country': 'Monaco',
#   'CountryCode': 'MC',
#   'Slug': 'monaco',
#   'NewConfirmed': 44,
#   'TotalConfirmed': 14852,
#   'NewDeaths': 0,
#   'TotalDeaths': 63,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'a28a555f-2f34-442b-a334-23e65947933e',
#   'Country': 'Mongolia',
#   'CountryCode': 'MN',
#   'Slug': 'mongolia',
#   'NewConfirmed': 35,
#   'TotalConfirmed': 984144,
#   'NewDeaths': 0,
#   'TotalDeaths': 2131,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'aaa670fa-75d4-43d4-89af-83079c41e06e',
#   'Country': 'Montenegro',
#   'CountryCode': 'ME',
#   'Slug': 'montenegro',
#   'NewConfirmed': 73,
#   'TotalConfirmed': 282052,
#   'NewDeaths': 0,
#   'TotalDeaths': 2784,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'e9c3b448-6a50-4102-a9e8-6ff1c3a84f0d',
#   'Country': 'Morocco',
#   'CountryCode': 'MA',
#   'Slug': 'morocco',
#   'NewConfirmed': 36,
#   'TotalConfirmed': 1265301,
#   'NewDeaths': 0,
#   'TotalDeaths': 16280,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'a9cf29a5-7b4d-4692-9bb7-396189d38353',
#   'Country': 'Mozambique',
#   'CountryCode': 'MZ',
#   'Slug': 'mozambique',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 230370,
#   'NewDeaths': 0,
#   'TotalDeaths': 2224,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '19dd4f13-faf6-47b2-bd81-f82b639b165d',
#   'Country': 'Myanmar',
#   'CountryCode': 'MM',
#   'Slug': 'myanmar',
#   'NewConfirmed': 277,
#   'TotalConfirmed': 629653,
#   'NewDeaths': 1,
#   'TotalDeaths': 19472,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '9d35bbff-91f8-4d26-a680-c644899ab93f',
#   'Country': 'Namibia',
#   'CountryCode': 'NA',
#   'Slug': 'namibia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 169253,
#   'NewDeaths': 0,
#   'TotalDeaths': 4080,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '68e6356f-91da-48ca-951d-0f22723fbcb0',
#   'Country': 'Nauru',
#   'CountryCode': 'NR',
#   'Slug': 'nauru',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 4611,
#   'NewDeaths': 0,
#   'TotalDeaths': 1,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'b3057fae-c96e-4087-ad58-e1fea117d57f',
#   'Country': 'Nepal',
#   'CountryCode': 'NP',
#   'Slug': 'nepal',
#   'NewConfirmed': 42,
#   'TotalConfirmed': 1000275,
#   'NewDeaths': 0,
#   'TotalDeaths': 12018,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '4d13ec8c-688b-4ae3-9a18-4e4f97416510',
#   'Country': 'Netherlands',
#   'CountryCode': 'NL',
#   'Slug': 'netherlands',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 8487576,
#   'NewDeaths': 0,
#   'TotalDeaths': 22748,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '8452a1f9-c146-401f-a96a-aed11a83edaf',
#   'Country': 'New Zealand',
#   'CountryCode': 'NZ',
#   'Slug': 'new-zealand',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1821362,
#   'NewDeaths': 0,
#   'TotalDeaths': 2066,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '0eb02294-cbe8-4f9b-ab13-e13ad57cce85',
#   'Country': 'Nicaragua',
#   'CountryCode': 'NI',
#   'Slug': 'nicaragua',
#   'NewConfirmed': 25,
#   'TotalConfirmed': 15145,
#   'NewDeaths': 0,
#   'TotalDeaths': 245,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'd37b0771-7114-4f4b-b101-16b1d061185b',
#   'Country': 'Niger',
#   'CountryCode': 'NE',
#   'Slug': 'niger',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 9415,
#   'NewDeaths': 0,
#   'TotalDeaths': 314,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '741112bc-b7ef-4ee8-89ab-985f2c988df1',
#   'Country': 'Nigeria',
#   'CountryCode': 'NG',
#   'Slug': 'nigeria',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 265937,
#   'NewDeaths': 0,
#   'TotalDeaths': 3155,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '700d9583-cab0-4439-b7a4-e13519f37f70',
#   'Country': 'Norway',
#   'CountryCode': 'NO',
#   'Slug': 'norway',
#   'NewConfirmed': 83,
#   'TotalConfirmed': 1463751,
#   'NewDeaths': 1,
#   'TotalDeaths': 4154,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '2565a07b-3c98-41f2-82b3-6f57c0e0c304',
#   'Country': 'Oman',
#   'CountryCode': 'OM',
#   'Slug': 'oman',
#   'NewConfirmed': 236,
#   'TotalConfirmed': 398660,
#   'NewDeaths': 0,
#   'TotalDeaths': 4628,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '03df6156-3e91-47eb-9165-03486d5b20bd',
#   'Country': 'Pakistan',
#   'CountryCode': 'PK',
#   'Slug': 'pakistan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1572778,
#   'NewDeaths': 0,
#   'TotalDeaths': 30619,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'de743d91-70f7-4b60-b77f-daa60c9bad45',
#   'Country': 'Palau',
#   'CountryCode': 'PW',
#   'Slug': 'palau',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 5490,
#   'NewDeaths': 0,
#   'TotalDeaths': 7,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '3e12c0b0-d027-464f-bf2c-5cc295a2211b',
#   'Country': 'Palestinian Territory',
#   'CountryCode': 'PS',
#   'Slug': 'palestine',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 702804,
#   'NewDeaths': 0,
#   'TotalDeaths': 5707,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '648e5b7a-ef11-495d-973e-f31b23b950e4',
#   'Country': 'Panama',
#   'CountryCode': 'PA',
#   'Slug': 'panama',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 989005,
#   'NewDeaths': 0,
#   'TotalDeaths': 8506,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '3bd6d454-bf17-430b-98f0-3ec301bdf271',
#   'Country': 'Papua New Guinea',
#   'CountryCode': 'PG',
#   'Slug': 'papua-new-guinea',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 45264,
#   'NewDeaths': 0,
#   'TotalDeaths': 668,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '0f779d8c-f371-4350-88f7-54a578cd4fcc',
#   'Country': 'Paraguay',
#   'CountryCode': 'PY',
#   'Slug': 'paraguay',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 717260,
#   'NewDeaths': 0,
#   'TotalDeaths': 19596,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '72df5bb4-c5c6-443d-8920-6421a4287685',
#   'Country': 'Peru',
#   'CountryCode': 'PE',
#   'Slug': 'peru',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 4150737,
#   'NewDeaths': 0,
#   'TotalDeaths': 216877,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '4734ea9c-e930-46fd-ae65-2b45b6a58b51',
#   'Country': 'Philippines',
#   'CountryCode': 'PH',
#   'Slug': 'philippines',
#   'NewConfirmed': 1288,
#   'TotalConfirmed': 3987316,
#   'NewDeaths': 44,
#   'TotalDeaths': 63625,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '5fcf3e84-0680-4fad-8441-5c6ccf51b2cf',
#   'Country': 'Poland',
#   'CountryCode': 'PL',
#   'Slug': 'poland',
#   'NewConfirmed': 1611,
#   'TotalConfirmed': 6330904,
#   'NewDeaths': 42,
#   'TotalDeaths': 117973,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '1728291f-49ac-4f0b-a3f5-03fd56c33811',
#   'Country': 'Portugal',
#   'CountryCode': 'PT',
#   'Slug': 'portugal',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 5509424,
#   'NewDeaths': 0,
#   'TotalDeaths': 25128,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '83b4a6fd-9ee1-49a1-943f-f23b3783ab25',
#   'Country': 'Qatar',
#   'CountryCode': 'QA',
#   'Slug': 'qatar',
#   'NewConfirmed': 560,
#   'TotalConfirmed': 463888,
#   'NewDeaths': 0,
#   'TotalDeaths': 683,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '731352cb-1978-4497-b370-57b9352dd2e5',
#   'Country': 'Republic of Kosovo',
#   'CountryCode': 'XK',
#   'Slug': 'kosovo',
#   'NewConfirmed': 4,
#   'TotalConfirmed': 272129,
#   'NewDeaths': 0,
#   'TotalDeaths': 3201,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '49dd8e15-d259-45cf-a7e2-6565c3b7445e',
#   'Country': 'Romania',
#   'CountryCode': 'RO',
#   'Slug': 'romania',
#   'NewConfirmed': 619,
#   'TotalConfirmed': 3281666,
#   'NewDeaths': 14,
#   'TotalDeaths': 67145,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '337939dd-4e7b-408d-b150-478202897877',
#   'Country': 'Russian Federation',
#   'CountryCode': 'RU',
#   'Slug': 'russia',
#   'NewConfirmed': 10595,
#   'TotalConfirmed': 21031202,
#   'NewDeaths': 90,
#   'TotalDeaths': 381314,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '3c70b6bf-11f1-4cd8-8a0b-ee3e829f71a3',
#   'Country': 'Rwanda',
#   'CountryCode': 'RW',
#   'Slug': 'rwanda',
#   'NewConfirmed': 3,
#   'TotalConfirmed': 132533,
#   'NewDeaths': 0,
#   'TotalDeaths': 1467,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'f63c310d-adcc-40b2-93f0-bd687d16681d',
#   'Country': 'Saint Kitts and Nevis',
#   'CountryCode': 'KN',
#   'Slug': 'saint-kitts-and-nevis',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 6547,
#   'NewDeaths': 0,
#   'TotalDeaths': 46,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '3d79d277-2e9e-4786-a8f1-e6b62ef85d49',
#   'Country': 'Saint Lucia',
#   'CountryCode': 'LC',
#   'Slug': 'saint-lucia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 29550,
#   'NewDeaths': 0,
#   'TotalDeaths': 405,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '9d81438c-330b-4d51-9752-8fe42f4f11a3',
#   'Country': 'Saint Vincent and Grenadines',
#   'CountryCode': 'VC',
#   'Slug': 'saint-vincent-and-the-grenadines',
#   'NewConfirmed': 2,
#   'TotalConfirmed': 9452,
#   'NewDeaths': 0,
#   'TotalDeaths': 116,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '7c5ec0fd-6a08-47a0-906e-e925ce72d42b',
#   'Country': 'Samoa',
#   'CountryCode': 'WS',
#   'Slug': 'samoa',
#   'NewConfirmed': 4,
#   'TotalConfirmed': 15946,
#   'NewDeaths': 0,
#   'TotalDeaths': 29,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '26b930b3-1c77-45bd-bec1-ecf3db78dd3a',
#   'Country': 'San Marino',
#   'CountryCode': 'SM',
#   'Slug': 'san-marino',
#   'NewConfirmed': 37,
#   'TotalConfirmed': 21400,
#   'NewDeaths': 0,
#   'TotalDeaths': 118,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '556cde14-b976-4dbe-92f8-e80e5b7704b0',
#   'Country': 'Sao Tome and Principe',
#   'CountryCode': 'ST',
#   'Slug': 'sao-tome-and-principe',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 6263,
#   'NewDeaths': 0,
#   'TotalDeaths': 77,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'ddd8d96f-d4c6-4ad6-97ca-366df8ba9875',
#   'Country': 'Saudi Arabia',
#   'CountryCode': 'SA',
#   'Slug': 'saudi-arabia',
#   'NewConfirmed': 247,
#   'TotalConfirmed': 819570,
#   'NewDeaths': 3,
#   'TotalDeaths': 9387,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'e5f5047e-08c1-4a65-be42-df2da7634cb1',
#   'Country': 'Senegal',
#   'CountryCode': 'SN',
#   'Slug': 'senegal',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 88630,
#   'NewDeaths': 0,
#   'TotalDeaths': 1968,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '722432dc-da04-4a9f-8b5b-6fb907b60cd2',
#   'Country': 'Serbia',
#   'CountryCode': 'RS',
#   'Slug': 'serbia',
#   'NewConfirmed': 1318,
#   'TotalConfirmed': 2392745,
#   'NewDeaths': 8,
#   'TotalDeaths': 17162,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'e405fba0-966d-4aa5-a199-43e2540f051f',
#   'Country': 'Seychelles',
#   'CountryCode': 'SC',
#   'Slug': 'seychelles',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 47141,
#   'NewDeaths': 0,
#   'TotalDeaths': 170,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '8572b0b3-a44b-4228-94c2-d2d5bcd36c8f',
#   'Country': 'Sierra Leone',
#   'CountryCode': 'SL',
#   'Slug': 'sierra-leone',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 7752,
#   'NewDeaths': 0,
#   'TotalDeaths': 126,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '0655c71f-7a4f-4faa-9434-52552f03a469',
#   'Country': 'Singapore',
#   'CountryCode': 'SG',
#   'Slug': 'singapore',
#   'NewConfirmed': 8752,
#   'TotalConfirmed': 2037947,
#   'NewDeaths': 3,
#   'TotalDeaths': 1654,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'f8cee980-0c1d-4124-b175-8608ccb96f6d',
#   'Country': 'Slovakia',
#   'CountryCode': 'SK',
#   'Slug': 'slovakia',
#   'NewConfirmed': 670,
#   'TotalConfirmed': 2638637,
#   'NewDeaths': 7,
#   'TotalDeaths': 20530,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '7f63232c-d0e0-4853-906d-ccc0e75f7de5',
#   'Country': 'Slovenia',
#   'CountryCode': 'SI',
#   'Slug': 'slovenia',
#   'NewConfirmed': 1794,
#   'TotalConfirmed': 1220889,
#   'NewDeaths': 6,
#   'TotalDeaths': 6864,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '11366029-3957-4c95-8b8c-0c8a054b1da3',
#   'Country': 'Solomon Islands',
#   'CountryCode': 'SB',
#   'Slug': 'solomon-islands',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 21544,
#   'NewDeaths': 0,
#   'TotalDeaths': 153,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '27c83762-8dcc-4072-b4b3-50a58c3aac07',
#   'Country': 'Somalia',
#   'CountryCode': 'SO',
#   'Slug': 'somalia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 27223,
#   'NewDeaths': 0,
#   'TotalDeaths': 1361,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'ba9bf4cf-4ed2-4d7a-a8c8-c4a60232f08f',
#   'Country': 'South Africa',
#   'CountryCode': 'ZA',
#   'Slug': 'south-africa',
#   'NewConfirmed': 424,
#   'TotalConfirmed': 4024553,
#   'NewDeaths': 0,
#   'TotalDeaths': 102246,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '97ac3f22-27fc-42d4-b943-3d52b613c1d6',
#   'Country': 'South Sudan',
#   'CountryCode': 'SS',
#   'Slug': 'south-sudan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 17823,
#   'NewDeaths': 0,
#   'TotalDeaths': 138,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '697ee80f-f807-41e9-8a1f-a9fcc4f76c91',
#   'Country': 'Spain',
#   'CountryCode': 'ES',
#   'Slug': 'spain',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 13462593,
#   'NewDeaths': 0,
#   'TotalDeaths': 114641,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '8307362c-9e94-4ea2-8016-27541b58f1a2',
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Slug': 'sri-lanka',
#   'NewConfirmed': 10,
#   'TotalConfirmed': 670952,
#   'NewDeaths': 2,
#   'TotalDeaths': 16772,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '26fa3c48-3c4f-4732-9450-b13430f35500',
#   'Country': 'Sudan',
#   'CountryCode': 'SD',
#   'Slug': 'sudan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 63449,
#   'NewDeaths': 1,
#   'TotalDeaths': 4965,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '69bd5bfe-dd79-4696-ad1f-20c823e97dc2',
#   'Country': 'Suriname',
#   'CountryCode': 'SR',
#   'Slug': 'suriname',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 81158,
#   'NewDeaths': 0,
#   'TotalDeaths': 1386,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'fa55a972-c4e0-49c8-bcf5-7cf25793e0e7',
#   'Country': 'Swaziland',
#   'CountryCode': 'SZ',
#   'Slug': 'swaziland',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 73436,
#   'NewDeaths': 0,
#   'TotalDeaths': 1422,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '60b7f587-36f4-4963-bf80-ad824d26bff6',
#   'Country': 'Sweden',
#   'CountryCode': 'SE',
#   'Slug': 'sweden',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 2604866,
#   'NewDeaths': 0,
#   'TotalDeaths': 20438,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '2fe48e3c-e1ab-49bc-a80b-92d1b87ce82f',
#   'Country': 'Switzerland',
#   'CountryCode': 'CH',
#   'Slug': 'switzerland',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 4164685,
#   'NewDeaths': 10,
#   'TotalDeaths': 14041,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '2fcea95a-92a3-44af-abe5-de01a8dd61f1',
#   'Country': 'Syrian Arab Republic (Syria)',
#   'CountryCode': 'SY',
#   'Slug': 'syria',
#   'NewConfirmed': 2,
#   'TotalConfirmed': 57340,
#   'NewDeaths': 0,
#   'TotalDeaths': 3163,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'd7f3be1f-98ca-40bf-8e75-fe5cfcb7bf43',
#   'Country': 'Taiwan, Republic of China',
#   'CountryCode': 'TW',
#   'Slug': 'taiwan',
#   'NewConfirmed': 44596,
#   'TotalConfirmed': 7302188,
#   'NewDeaths': 42,
#   'TotalDeaths': 12036,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '669bbc33-ed3e-47b7-8f6c-89ec71562587',
#   'Country': 'Tajikistan',
#   'CountryCode': 'TJ',
#   'Slug': 'tajikistan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 17786,
#   'NewDeaths': 0,
#   'TotalDeaths': 125,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '24f5532d-3a04-4ae4-83c2-c02f9921bea1',
#   'Country': 'Tanzania, United Republic of',
#   'CountryCode': 'TZ',
#   'Slug': 'tanzania',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 39679,
#   'NewDeaths': 0,
#   'TotalDeaths': 845,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '0b3e4f30-2fc2-4888-a100-c8c1727b0730',
#   'Country': 'Thailand',
#   'CountryCode': 'TH',
#   'Slug': 'thailand',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 4687281,
#   'NewDeaths': 0,
#   'TotalDeaths': 32882,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'c37436bc-1d8a-4fca-a732-d6be0fe886fd',
#   'Country': 'Timor-Leste',
#   'CountryCode': 'TL',
#   'Slug': 'timor-leste',
#   'NewConfirmed': 3,
#   'TotalConfirmed': 23291,
#   'NewDeaths': 0,
#   'TotalDeaths': 138,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'fb9ce617-3d07-4b52-96ed-19768459d524',
#   'Country': 'Togo',
#   'CountryCode': 'TG',
#   'Slug': 'togo',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 39261,
#   'NewDeaths': 0,
#   'TotalDeaths': 288,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'ee9a0c66-90cc-4394-b72d-ee6c7163989c',
#   'Country': 'Tonga',
#   'CountryCode': 'TO',
#   'Slug': 'tonga',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 16182,
#   'NewDeaths': 0,
#   'TotalDeaths': 12,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'f6b36eb6-939e-48b7-a795-1efe2843542a',
#   'Country': 'Trinidad and Tobago',
#   'CountryCode': 'TT',
#   'Slug': 'trinidad-and-tobago',
#   'NewConfirmed': 263,
#   'TotalConfirmed': 184524,
#   'NewDeaths': 6,
#   'TotalDeaths': 4241,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '6d84c35a-da68-4717-a9a1-1774a2b608df',
#   'Country': 'Tunisia',
#   'CountryCode': 'TN',
#   'Slug': 'tunisia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1146044,
#   'NewDeaths': 0,
#   'TotalDeaths': 29257,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '6a65e181-93a1-40e6-8a9d-72bfeb8c6c40',
#   'Country': 'Turkey',
#   'CountryCode': 'TR',
#   'Slug': 'turkey',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 16919638,
#   'NewDeaths': 0,
#   'TotalDeaths': 101203,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'a3957f50-da71-409c-8bd1-9e02e6579438',
#   'Country': 'Tuvalu',
#   'CountryCode': 'TV',
#   'Slug': 'tuvalu',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 20,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '815303fb-7e31-4a34-918a-44ee601179c8',
#   'Country': 'Uganda',
#   'CountryCode': 'UG',
#   'Slug': 'uganda',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 169396,
#   'NewDeaths': 0,
#   'TotalDeaths': 3630,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'e935c4c0-f897-4b3d-a17d-6f828be38e58',
#   'Country': 'Ukraine',
#   'CountryCode': 'UA',
#   'Slug': 'ukraine',
#   'NewConfirmed': 61,
#   'TotalConfirmed': 5583231,
#   'NewDeaths': 2,
#   'TotalDeaths': 117681,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '1c456882-6fb0-483c-b393-7a6a71bd43b7',
#   'Country': 'United Arab Emirates',
#   'CountryCode': 'AE',
#   'Slug': 'united-arab-emirates',
#   'NewConfirmed': 312,
#   'TotalConfirmed': 1033770,
#   'NewDeaths': 0,
#   'TotalDeaths': 2347,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '03062ec1-f0ed-4d04-bd6d-8ff5540570bc',
#   'Country': 'United Kingdom',
#   'CountryCode': 'GB',
#   'Slug': 'united-kingdom',
#   'NewConfirmed': 177,
#   'TotalConfirmed': 24021973,
#   'NewDeaths': 0,
#   'TotalDeaths': 208678,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '41881db7-7961-486c-94ef-992d786e330c',
#   'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Slug': 'united-states',
#   'NewConfirmed': 60137,
#   'TotalConfirmed': 97083662,
#   'NewDeaths': 746,
#   'TotalDeaths': 1066584,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '76795411-affa-41fc-b164-9148d3d92772',
#   'Country': 'Uruguay',
#   'CountryCode': 'UY',
#   'Slug': 'uruguay',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 988527,
#   'NewDeaths': 0,
#   'TotalDeaths': 7510,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '0cd7c686-e389-4295-a035-818df1967cee',
#   'Country': 'Uzbekistan',
#   'CountryCode': 'UZ',
#   'Slug': 'uzbekistan',
#   'NewConfirmed': 3,
#   'TotalConfirmed': 244424,
#   'NewDeaths': 0,
#   'TotalDeaths': 1637,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'b18aa221-509f-4126-96bf-e810a55e1822',
#   'Country': 'Vanuatu',
#   'CountryCode': 'VU',
#   'Slug': 'vanuatu',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 11976,
#   'NewDeaths': 0,
#   'TotalDeaths': 14,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '563c05d6-aa54-4170-9b9b-8432df6b8704',
#   'Country': 'Venezuela (Bolivarian Republic)',
#   'CountryCode': 'VE',
#   'Slug': 'venezuela',
#   'NewConfirmed': 92,
#   'TotalConfirmed': 545469,
#   'NewDeaths': 0,
#   'TotalDeaths': 5820,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'e7d97897-9297-4b0f-846e-ac47d9af268f',
#   'Country': 'Viet Nam',
#   'CountryCode': 'VN',
#   'Slug': 'vietnam',
#   'NewConfirmed': 1337,
#   'TotalConfirmed': 11495231,
#   'NewDeaths': 1,
#   'TotalDeaths': 43159,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '69b2855a-ebed-43a7-9e54-bc8e02262810',
#   'Country': 'Yemen',
#   'CountryCode': 'YE',
#   'Slug': 'yemen',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 11939,
#   'NewDeaths': 0,
#   'TotalDeaths': 2158,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': 'e1d8f70a-df14-4912-94e4-5e33a4580362',
#   'Country': 'Zambia',
#   'CountryCode': 'ZM',
#   'Slug': 'zambia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 333644,
#   'NewDeaths': 0,
#   'TotalDeaths': 4017,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}},
#  {'ID': '67427123-6e14-4a7d-9266-4d04f67b9a37',
#   'Country': 'Zimbabwe',
#   'CountryCode': 'ZW',
#   'Slug': 'zimbabwe',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 257893,
#   'NewDeaths': 0,
#   'TotalDeaths': 5606,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-10-21T03:07:56.806Z',
#   'Premium': {}}]
